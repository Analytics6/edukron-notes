# %% [raw]
# ---
# title: false
# page-layout: full
# toc: false
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <section class="hero">
#   <div class="hero-kicker">Notebook-first learning library</div>
#   <h1>Learn technology by working through it.</h1>
#   <p>Edukron Notes organizes AI, data engineering, and DevOps into clear learning paths. Every published lesson is a Jupyter notebook designed for notes, examples, outputs, practice, and revision.</p>
#   <div class="hero-actions"><a href="courses/full-stack-ai/index.html">Explore Full Stack AI</a><a href="courses/azure-data-engineering/index.html">Explore Data Engineering</a></div>
# </section>

# %% [markdown]
# ## Top-level learning paths
#
# <div class="feature-grid program-grid">
#   <a class="course-card" href="courses/full-stack-ai/index.html"><span class="course-number">Top-level menu</span><strong>Full Stack AI</strong><span>A complete path from programming and data foundations to production-ready generative and agentic AI systems.</span></a>
#   <a class="course-card" href="courses/azure-data-engineering/index.html"><span class="course-number">Top-level menu</span><strong>Azure Data Engineering</strong><span>An end-to-end path for designing, building, governing, and operating modern data platforms on Azure.</span></a>
#   <a class="course-card" href="courses/azure-devops/index.html"><span class="course-number">Top-level menu</span><strong>Azure DevOps</strong><span>A practical path from source control and automation to secure cloud delivery, containers, infrastructure, and operations.</span></a>
#   <a class="course-card" href="interview-questions/index.html"><span class="course-number">Top-level menu</span><strong>Interview Questions</strong><span>Structured preparation pages for concept checks, scenario questions, coding discussions, and system-design interviews.</span></a>
#   <a class="course-card" href="project-flows/index.html"><span class="course-number">Top-level menu</span><strong>Project Flows</strong><span>End-to-end implementation maps that connect requirements, architecture, delivery, testing, deployment, and operations.</span></a>
# </div>

# %% [markdown]
# ## Curriculum status
#
# The complete navigation and individual overview pages are ready. Detailed module notebooks will be added from the course contents you provide next.
#
# <div class="overview-meta home-meta">
#   <div><span>Course overviews</span><strong>30</strong></div>
#   <div><span>Interview overviews</span><strong>3</strong></div>
#   <div><span>Project-flow overviews</span><strong>3</strong></div>
# </div>
