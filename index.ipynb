# %% [raw]
# ---
# title: false
# page-layout: full
# toc: false
# title-block-banner: false
# listing:
#   contents:
#     - posts/gradient-descent.ipynb
#     - posts/model-evaluation.ipynb
#     - courses/data-science/python-data-analysis.ipynb
#     - courses/data-science/data-cleaning.ipynb
#     - courses/data-science/exploratory-analysis.ipynb
#     - courses/machine-learning/kmeans-from-scratch.ipynb
#     - courses/artificial-intelligence/search-and-astar.ipynb
#     - courses/artificial-intelligence/neural-network-from-scratch.ipynb
#     - courses/artificial-intelligence/language-models-and-attention.ipynb
#     - posts/publish-cloud.ipynb
#   sort: "date desc"
#   type: default
#   categories: true
#   sort-ui: false
#   filter-ui: true
#   page-size: 10
# ---

# %% [markdown]
# <section class="hero">
#   <div class="hero-kicker">A complete notebook learning library</div>
#   <h1>Learn data and AI by running it.</h1>
#   <p>Structured courses in data science, machine learning, and artificial intelligence—every lesson is a runnable Jupyter notebook with explanations, exercises, and real outputs.</p>
#   <div class="hero-actions"><a href="courses/data-science/index.html">Start learning</a><a href="posts/publish-cloud.html">See how the academy is built</a></div>
# </section>

# %% [markdown]
# ## Choose a learning path
#
# <div class="feature-grid">
#   <a class="course-card" href="courses/data-science/index.html"><span class="course-number">Course 01</span><strong>Data Science</strong><span>Python, cleaning, analysis, visualization, and defensible conclusions.</span></a>
#   <a class="course-card" href="courses/machine-learning/index.html"><span class="course-number">Course 02</span><strong>Machine Learning</strong><span>Optimization, evaluation, supervised learning, and clustering from first principles.</span></a>
#   <a class="course-card" href="courses/artificial-intelligence/index.html"><span class="course-number">Course 03</span><strong>Artificial Intelligence</strong><span>Search, neural networks, language models, and attention with runnable code.</span></a>
# </div>

# %% [markdown]
# ## Latest notebooks
#
# Browse the newest tutorials below, or use the course menus above to follow a complete sequence from foundations to implementation.
