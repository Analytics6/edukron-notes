# %% [raw]
# ---
# title: "Azure DevOps — Overview"
# description: "A practical path from source control and automation to secure cloud delivery, containers, infrastructure, and operations."
# author: "Edukron Notes"
# date: "2026-09-09"
# categories: [program-overview, azure-devops]
# toc: true
# page-layout: article
# execute: false
# ---

# %% [markdown]
# <section class="program-intro">
#   <div class="overview-lead">
#     <span class="topic-icon"><i class="bi bi-infinity" aria-hidden="true"></i></span>
#     <div><span class="overview-eyebrow">Learning path</span><p>A practical path from source control and automation to secure cloud delivery, containers, infrastructure, and operations.</p></div>
#   </div>
# </section>
#
# ::: {.callout-tip}
# ### Course map
# Each subject has a dedicated overview. Detailed notebooks are added in the approved learning sequence.
# :::

# %% [markdown]
# ## Choose an overview
#
# <div class="feature-grid curriculum-grid">
#   <a class="course-card" href="linux-shell-scripting.html"><span class="card-icon"><i class="bi bi-terminal" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Linux & Shell Scripting</strong><span>Command-line fluency and dependable scripts for delivery and operations.</span></a>
#   <a class="course-card" href="git-version-control.html"><span class="card-icon"><i class="bi bi-git" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Git & Version Control</strong><span>Commit design, branching, collaboration, recovery, and maintainable history.</span></a>
#   <a class="course-card" href="azure-repos.html"><span class="card-icon"><i class="bi bi-folder2-open" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Azure Repos</strong><span>Repository policies, pull requests, permissions, and team collaboration on Azure DevOps.</span></a>
#   <a class="course-card" href="azure-pipelines.html"><span class="card-icon"><i class="bi bi-infinity" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Azure Pipelines (CI/CD)</strong><span>Automated build, test, release, environments, approvals, and deployment strategies.</span></a>
#   <a class="course-card" href="yaml-pipelines.html"><span class="card-icon"><i class="bi bi-filetype-yml" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>YAML Pipeline Development</strong><span>Reusable, parameterized, secure, and testable pipeline definitions.</span></a>
#   <a class="course-card" href="docker.html"><span class="card-icon"><i class="bi bi-box-seam" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Docker & Containerization</strong><span>Images, containers, registries, networking, security, and production practices.</span></a>
#   <a class="course-card" href="kubernetes-aks.html"><span class="card-icon"><i class="bi bi-boxes" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Kubernetes & AKS</strong><span>Workload orchestration, networking, scaling, upgrades, and Azure Kubernetes Service.</span></a>
#   <a class="course-card" href="terraform.html"><span class="card-icon"><i class="bi bi-building" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Terraform Infrastructure as Code (IaC)</strong><span>Repeatable Azure infrastructure using state, modules, plans, and automation.</span></a>
#   <a class="course-card" href="azure-cloud-services.html"><span class="card-icon"><i class="bi bi-cloud" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Azure Cloud Services</strong><span>Choosing and integrating Azure compute, networking, identity, storage, and monitoring.</span></a>
#   <a class="course-card" href="devsecops-monitoring.html"><span class="card-icon"><i class="bi bi-shield-check" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>DevSecOps & Monitoring</strong><span>Security controls, supply-chain checks, telemetry, alerting, and incident learning.</span></a>
# </div>

# %% [markdown]
# ## Publishing standard
#
# All material in this section will remain notebook-first: white reading surfaces, clear explanations, runnable or copy-ready examples where appropriate, visible outputs, exercises, and concise recaps. Each approved module will receive its own Jupyter notebook and a stable place in this course map.
