# %% [raw]
# ---
# title: "DevSecOps & Monitoring"
# description: "Complete notebook syllabus for DevSecOps & Monitoring in Azure DevOps."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>devsecops-monitoring.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure DevOps</span>
# <h1>DevSecOps & Monitoring</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/01-shift-left-security.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-devops-devsecops-and-monitoring-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-devops-devsecops-and-monitoring-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the DevSecOps & Monitoring syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-devops-devsecops-and-monitoring-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 168</span><strong>DevSecOps foundations and supply-chain security</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/01-shift-left-security.html"><span>168.01</span><strong>Shift-left security</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/02-threat-modeling.html"><span>168.02</span><strong>Threat modeling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/03-secure-coding.html"><span>168.03</span><strong>Secure coding</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/04-dependency-scanning.html"><span>168.04</span><strong>Dependency scanning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/05-secret-scanning.html"><span>168.05</span><strong>Secret scanning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/06-sast.html"><span>168.06</span><strong>SAST</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/07-dast.html"><span>168.07</span><strong>DAST</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/08-container-scanning.html"><span>168.08</span><strong>Container scanning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/09-software-bills-of-materials.html"><span>168.09</span><strong>Software bills of materials</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/168-devsecops-foundations-and-supply-chain-security/10-security-pipeline-project.html"><span>168.10</span><strong>Security-pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 169</span><strong>Observability and incident response</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/01-logs-metrics-and-traces.html"><span>169.01</span><strong>Logs metrics and traces</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/02-telemetry-design.html"><span>169.02</span><strong>Telemetry design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/03-service-level-indicators.html"><span>169.03</span><strong>Service-level indicators</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/04-service-level-objectives.html"><span>169.04</span><strong>Service-level objectives</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/05-dashboards.html"><span>169.05</span><strong>Dashboards</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/06-alert-design.html"><span>169.06</span><strong>Alert design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/07-distributed-tracing.html"><span>169.07</span><strong>Distributed tracing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/08-incident-response.html"><span>169.08</span><strong>Incident response</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/09-post-incident-reviews.html"><span>169.09</span><strong>Post-incident reviews</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/169-observability-and-incident-response/10-observability-project.html"><span>169.10</span><strong>Observability project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 170</span><strong>Secure delivery and monitoring capstone</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/01-security-architecture.html"><span>170.01</span><strong>Security architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/02-policy-as-code.html"><span>170.02</span><strong>Policy as code</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/03-identity-controls.html"><span>170.03</span><strong>Identity controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/04-release-controls.html"><span>170.04</span><strong>Release controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/05-runtime-protection.html"><span>170.05</span><strong>Runtime protection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/06-vulnerability-management.html"><span>170.06</span><strong>Vulnerability management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/07-compliance-evidence.html"><span>170.07</span><strong>Compliance evidence</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/08-resilience-testing.html"><span>170.08</span><strong>Resilience testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/09-operational-readiness.html"><span>170.09</span><strong>Operational readiness</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="devsecops-monitoring/170-secure-delivery-and-monitoring-capstone/10-devsecops-capstone.html"><span>170.10</span><strong>DevSecOps capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-devops-devsecops-and-monitoring-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-devops-devsecops-and-monitoring-catalog");
#   const search = document.getElementById("azure-devops-devsecops-and-monitoring-catalog-search");
#   const empty = document.getElementById("azure-devops-devsecops-and-monitoring-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **DevSecOps & Monitoring** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
