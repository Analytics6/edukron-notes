# %% [raw]
# ---
# title: "Docker & Containerization"
# description: "Complete notebook syllabus for Docker & Containerization in Azure DevOps."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>docker.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure DevOps</span>
# <h1>Docker & Containerization</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="docker/150-container-foundations/01-containers-versus-virtual-machines.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Docker & Containerization with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>6 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Container foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="docker/150-container-foundations/01-containers-versus-virtual-machines.html">Containers versus virtual machines</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="docker/150-container-foundations/10-first-container-project.html">First container project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Building Docker images</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="docker/151-building-docker-images/01-dockerfile-syntax.html">Dockerfile syntax</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="docker/151-building-docker-images/10-optimized-image-project.html">Optimized-image project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Docker networking and storage</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="docker/152-docker-networking-and-storage/01-network-drivers.html">Network drivers</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="docker/152-docker-networking-and-storage/10-stateful-container-lab.html">Stateful-container lab</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Compose and container registries</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="docker/153-compose-and-container-registries/01-compose-files.html">Compose files</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="docker/153-compose-and-container-registries/10-compose-project.html">Compose project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Container security and production practices</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="docker/154-container-security-and-production-practices/01-image-scanning.html">Image scanning</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="docker/154-container-security-and-production-practices/10-docker-capstone.html">Docker capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 06</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Docker & Containerization outcome. Use <a href="docker/154-container-security-and-production-practices/10-docker-capstone.html">Docker capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure DevOps → Docker & Containerization</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="150" href="docker/150-container-foundations/01-containers-versus-virtual-machines.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 150</span><strong>Container foundations</strong><small>Enter with Containers versus virtual machines. Demonstrate mastery through First container project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="151" href="docker/151-building-docker-images/01-dockerfile-syntax.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 151</span><strong>Building Docker images</strong><small>Enter with Dockerfile syntax. Demonstrate mastery through Optimized-image project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="152" href="docker/152-docker-networking-and-storage/01-network-drivers.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 152</span><strong>Docker networking and storage</strong><small>Enter with Network drivers. Demonstrate mastery through Stateful-container lab.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="153" href="docker/153-compose-and-container-registries/01-compose-files.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 153</span><strong>Compose and container registries</strong><small>Enter with Compose files. Demonstrate mastery through Compose project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="154" href="docker/154-container-security-and-production-practices/01-image-scanning.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 154</span><strong>Container security and production practices</strong><small>Enter with Image scanning. Demonstrate mastery through Docker capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Docker & Containerization workflow</strong><p>Combine evidence from every stage and finish with Docker capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-devops-docker-and-containerization-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-devops-docker-and-containerization-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Docker & Containerization syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-devops-docker-and-containerization-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 150</span><strong>Container foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="docker/150-container-foundations/01-containers-versus-virtual-machines.html"><span>150.01</span><strong>Containers versus virtual machines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/02-docker-architecture.html"><span>150.02</span><strong>Docker architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/03-installing-docker.html"><span>150.03</span><strong>Installing Docker</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/04-images-and-containers.html"><span>150.04</span><strong>Images and containers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/05-container-lifecycle.html"><span>150.05</span><strong>Container lifecycle</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/06-port-publishing.html"><span>150.06</span><strong>Port publishing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/07-environment-variables.html"><span>150.07</span><strong>Environment variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/08-logs.html"><span>150.08</span><strong>Logs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/09-resource-limits.html"><span>150.09</span><strong>Resource limits</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/150-container-foundations/10-first-container-project.html"><span>150.10</span><strong>First container project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 151</span><strong>Building Docker images</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="docker/151-building-docker-images/01-dockerfile-syntax.html"><span>151.01</span><strong>Dockerfile syntax</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/02-base-image-selection.html"><span>151.02</span><strong>Base-image selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/03-build-context.html"><span>151.03</span><strong>Build context</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/04-layer-caching.html"><span>151.04</span><strong>Layer caching</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/05-multi-stage-builds.html"><span>151.05</span><strong>Multi-stage builds</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/06-build-arguments.html"><span>151.06</span><strong>Build arguments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/07-image-metadata.html"><span>151.07</span><strong>Image metadata</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/08-non-root-users.html"><span>151.08</span><strong>Non-root users</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/09-image-testing.html"><span>151.09</span><strong>Image testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/151-building-docker-images/10-optimized-image-project.html"><span>151.10</span><strong>Optimized-image project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 152</span><strong>Docker networking and storage</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/01-network-drivers.html"><span>152.01</span><strong>Network drivers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/02-bridge-networks.html"><span>152.02</span><strong>Bridge networks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/03-dns-and-service-discovery.html"><span>152.03</span><strong>DNS and service discovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/04-port-mapping.html"><span>152.04</span><strong>Port mapping</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/05-volumes.html"><span>152.05</span><strong>Volumes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/06-bind-mounts.html"><span>152.06</span><strong>Bind mounts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/07-storage-permissions.html"><span>152.07</span><strong>Storage permissions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/08-backup-and-restore.html"><span>152.08</span><strong>Backup and restore</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/09-network-troubleshooting.html"><span>152.09</span><strong>Network troubleshooting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/152-docker-networking-and-storage/10-stateful-container-lab.html"><span>152.10</span><strong>Stateful-container lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 153</span><strong>Compose and container registries</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/01-compose-files.html"><span>153.01</span><strong>Compose files</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/02-multi-service-applications.html"><span>153.02</span><strong>Multi-service applications</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/03-dependencies.html"><span>153.03</span><strong>Dependencies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/04-profiles.html"><span>153.04</span><strong>Profiles</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/05-configuration.html"><span>153.05</span><strong>Configuration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/06-health-checks.html"><span>153.06</span><strong>Health checks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/07-registry-concepts.html"><span>153.07</span><strong>Registry concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/08-azure-container-registry.html"><span>153.08</span><strong>Azure Container Registry</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/09-image-tagging.html"><span>153.09</span><strong>Image tagging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/153-compose-and-container-registries/10-compose-project.html"><span>153.10</span><strong>Compose project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 154</span><strong>Container security and production practices</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/01-image-scanning.html"><span>154.01</span><strong>Image scanning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/02-supply-chain-metadata.html"><span>154.02</span><strong>Supply-chain metadata</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/03-secrets.html"><span>154.03</span><strong>Secrets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/04-capabilities.html"><span>154.04</span><strong>Capabilities</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/05-read-only-filesystems.html"><span>154.05</span><strong>Read-only filesystems</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/06-runtime-security.html"><span>154.06</span><strong>Runtime security</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/07-image-signing.html"><span>154.07</span><strong>Image signing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/08-patch-strategy.html"><span>154.08</span><strong>Patch strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/09-observability.html"><span>154.09</span><strong>Observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="docker/154-container-security-and-production-practices/10-docker-capstone.html"><span>154.10</span><strong>Docker capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-devops-docker-and-containerization-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-devops-docker-and-containerization-catalog");
#   const search = document.getElementById("azure-devops-docker-and-containerization-catalog-search");
#   const empty = document.getElementById("azure-devops-docker-and-containerization-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Docker & Containerization** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
