# %% [raw]
# ---
# title: "Kubernetes & AKS"
# description: "Complete notebook syllabus for Kubernetes & AKS in Azure DevOps."
# author: "Edukron Notes"
# date: "2026-09-14"
# toc: true
# execute: false
# ---

# %% [markdown]
# <div class="overview-lead curriculum-summary">
# <div class="overview-icon"><i class="bi bi-journal-code" aria-hidden="true"></i></div>
# <div><span class="overview-kicker">Azure DevOps</span><h2>Kubernetes & AKS</h2><p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson contains notes, a worked pattern, executable validation, a guided lab, solution blueprint, practice, and knowledge checks.</p></div>
# </div>
#
# <div class="course-stat-grid">
# <div><strong>6</strong><span>Syllabus topics</span></div>
# <div><strong>60</strong><span>Notebook lessons</span></div>
# <div><strong>Practice</strong><span>Labs and solutions</span></div>
# </div>
#
# <p class="course-start"><a class="btn btn-primary" href="kubernetes-aks/155-kubernetes-architecture/01-cluster-components.html">Start the first notebook <i class="bi bi-arrow-right"></i></a></p>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# ## Full syllabus
#
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 155</span><strong>Kubernetes architecture</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/01-cluster-components.html"><span>155.01</span><strong>Cluster components</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/02-control-plane.html"><span>155.02</span><strong>Control plane</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/03-worker-nodes.html"><span>155.03</span><strong>Worker nodes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/04-api-objects.html"><span>155.04</span><strong>API objects</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/05-namespaces.html"><span>155.05</span><strong>Namespaces</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/06-labels-and-selectors.html"><span>155.06</span><strong>Labels and selectors</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/07-kubectl.html"><span>155.07</span><strong>kubectl</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/08-declarative-management.html"><span>155.08</span><strong>Declarative management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/09-resource-specifications.html"><span>155.09</span><strong>Resource specifications</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/155-kubernetes-architecture/10-architecture-lab.html"><span>155.10</span><strong>Architecture lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 156</span><strong>Kubernetes workload objects</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/01-pods.html"><span>156.01</span><strong>Pods</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/02-replicasets.html"><span>156.02</span><strong>ReplicaSets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/03-deployments.html"><span>156.03</span><strong>Deployments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/04-statefulsets.html"><span>156.04</span><strong>StatefulSets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/05-daemonsets.html"><span>156.05</span><strong>DaemonSets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/06-jobs.html"><span>156.06</span><strong>Jobs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/07-cronjobs.html"><span>156.07</span><strong>CronJobs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/08-probes.html"><span>156.08</span><strong>Probes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/09-resource-requests-and-limits.html"><span>156.09</span><strong>Resource requests and limits</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/156-kubernetes-workload-objects/10-workload-project.html"><span>156.10</span><strong>Workload project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 157</span><strong>Configuration and storage</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/01-configmaps.html"><span>157.01</span><strong>ConfigMaps</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/02-secrets.html"><span>157.02</span><strong>Secrets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/03-environment-injection.html"><span>157.03</span><strong>Environment injection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/04-volumes.html"><span>157.04</span><strong>Volumes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/05-persistentvolumes.html"><span>157.05</span><strong>PersistentVolumes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/06-persistentvolumeclaims.html"><span>157.06</span><strong>PersistentVolumeClaims</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/07-storageclasses.html"><span>157.07</span><strong>StorageClasses</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/08-azure-disk.html"><span>157.08</span><strong>Azure Disk</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/09-azure-files.html"><span>157.09</span><strong>Azure Files</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/157-configuration-and-storage/10-stateful-workload-project.html"><span>157.10</span><strong>Stateful-workload project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 158</span><strong>Kubernetes networking and ingress</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/01-cluster-networking.html"><span>158.01</span><strong>Cluster networking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/02-services.html"><span>158.02</span><strong>Services</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/03-clusterip.html"><span>158.03</span><strong>ClusterIP</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/04-nodeport.html"><span>158.04</span><strong>NodePort</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/05-loadbalancer.html"><span>158.05</span><strong>LoadBalancer</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/06-ingress.html"><span>158.06</span><strong>Ingress</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/07-ingress-controllers.html"><span>158.07</span><strong>Ingress controllers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/08-network-policies.html"><span>158.08</span><strong>Network policies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/09-dns-troubleshooting.html"><span>158.09</span><strong>DNS troubleshooting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/158-kubernetes-networking-and-ingress/10-networking-lab.html"><span>158.10</span><strong>Networking lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 159</span><strong>Scaling upgrades and operations</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/01-horizontal-pod-autoscaler.html"><span>159.01</span><strong>Horizontal Pod Autoscaler</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/02-vertical-scaling.html"><span>159.02</span><strong>Vertical scaling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/03-cluster-autoscaler.html"><span>159.03</span><strong>Cluster autoscaler</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/04-pod-disruption-budgets.html"><span>159.04</span><strong>Pod disruption budgets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/05-rolling-updates.html"><span>159.05</span><strong>Rolling updates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/06-rollbacks.html"><span>159.06</span><strong>Rollbacks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/07-helm.html"><span>159.07</span><strong>Helm</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/08-logging.html"><span>159.08</span><strong>Logging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/09-metrics.html"><span>159.09</span><strong>Metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/159-scaling-upgrades-and-operations/10-operations-project.html"><span>159.10</span><strong>Operations project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 160</span><strong>Production Azure Kubernetes Service</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/01-aks-architecture.html"><span>160.01</span><strong>AKS architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/02-cluster-creation.html"><span>160.02</span><strong>Cluster creation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/03-entra-integration.html"><span>160.03</span><strong>Entra integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/04-managed-identities.html"><span>160.04</span><strong>Managed identities</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/05-acr-integration.html"><span>160.05</span><strong>ACR integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/06-node-pools.html"><span>160.06</span><strong>Node pools</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/07-private-clusters.html"><span>160.07</span><strong>Private clusters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/08-azure-policy.html"><span>160.08</span><strong>Azure Policy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/09-upgrade-planning.html"><span>160.09</span><strong>Upgrade planning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="kubernetes-aks/160-production-azure-kubernetes-service/10-aks-capstone.html"><span>160.10</span><strong>AKS capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>

# %% [markdown]
# ## Completion standard
#
# You have completed **Kubernetes & AKS** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
