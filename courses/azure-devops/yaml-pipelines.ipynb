# %% [raw]
# ---
# title: "YAML Pipeline Development"
# description: "Complete notebook syllabus for YAML Pipeline Development in Azure DevOps."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>yaml-pipelines.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure DevOps</span>
# <h1>YAML Pipeline Development</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="yaml-pipelines/146-yaml-pipeline-foundations/01-yaml-syntax.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing YAML Pipeline Development with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>5 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>3 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>YAML pipeline foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="yaml-pipelines/146-yaml-pipeline-foundations/01-yaml-syntax.html">YAML syntax</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="yaml-pipelines/146-yaml-pipeline-foundations/10-foundations-pipeline.html">Foundations pipeline</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Templates and reusable pipelines</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="yaml-pipelines/147-templates-and-reusable-pipelines/01-step-templates.html">Step templates</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="yaml-pipelines/147-templates-and-reusable-pipelines/10-reusable-pipeline-project.html">Reusable-pipeline project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Conditions dependencies and artifacts</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="yaml-pipelines/148-conditions-dependencies-and-artifacts/01-runtime-expressions.html">Runtime expressions</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="yaml-pipelines/148-conditions-dependencies-and-artifacts/10-orchestration-lab.html">Orchestration lab</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Secure production YAML</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="yaml-pipelines/149-secure-production-yaml/01-secret-variables.html">Secret variables</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="yaml-pipelines/149-secure-production-yaml/10-yaml-capstone.html">YAML capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 05</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable YAML Pipeline Development outcome. Use <a href="yaml-pipelines/149-secure-production-yaml/10-yaml-capstone.html">YAML capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure DevOps → YAML Pipeline Development</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="146" href="yaml-pipelines/146-yaml-pipeline-foundations/01-yaml-syntax.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 146</span><strong>YAML pipeline foundations</strong><small>Enter with YAML syntax. Demonstrate mastery through Foundations pipeline.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="147" href="yaml-pipelines/147-templates-and-reusable-pipelines/01-step-templates.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 147</span><strong>Templates and reusable pipelines</strong><small>Enter with Step templates. Demonstrate mastery through Reusable-pipeline project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="148" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/01-runtime-expressions.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 148</span><strong>Conditions dependencies and artifacts</strong><small>Enter with Runtime expressions. Demonstrate mastery through Orchestration lab.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="149" href="yaml-pipelines/149-secure-production-yaml/01-secret-variables.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 149</span><strong>Secure production YAML</strong><small>Enter with Secret variables. Demonstrate mastery through YAML capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete YAML Pipeline Development workflow</strong><p>Combine evidence from every stage and finish with YAML capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-devops-yaml-pipeline-development-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-devops-yaml-pipeline-development-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the YAML Pipeline Development syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-devops-yaml-pipeline-development-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 146</span><strong>YAML pipeline foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/01-yaml-syntax.html"><span>146.01</span><strong>YAML syntax</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/02-pipeline-schema.html"><span>146.02</span><strong>Pipeline schema</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/03-stages-jobs-and-steps.html"><span>146.03</span><strong>Stages jobs and steps</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/04-tasks-and-scripts.html"><span>146.04</span><strong>Tasks and scripts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/05-variables.html"><span>146.05</span><strong>Variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/06-parameters.html"><span>146.06</span><strong>Parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/07-triggers.html"><span>146.07</span><strong>Triggers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/08-agent-selection.html"><span>146.08</span><strong>Agent selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/09-expressions.html"><span>146.09</span><strong>Expressions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/146-yaml-pipeline-foundations/10-foundations-pipeline.html"><span>146.10</span><strong>Foundations pipeline</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 147</span><strong>Templates and reusable pipelines</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/01-step-templates.html"><span>147.01</span><strong>Step templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/02-job-templates.html"><span>147.02</span><strong>Job templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/03-stage-templates.html"><span>147.03</span><strong>Stage templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/04-variable-templates.html"><span>147.04</span><strong>Variable templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/05-template-parameters.html"><span>147.05</span><strong>Template parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/06-object-parameters.html"><span>147.06</span><strong>Object parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/07-extends-templates.html"><span>147.07</span><strong>Extends templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/08-template-repositories.html"><span>147.08</span><strong>Template repositories</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/09-versioning-templates.html"><span>147.09</span><strong>Versioning templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/147-templates-and-reusable-pipelines/10-reusable-pipeline-project.html"><span>147.10</span><strong>Reusable-pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 148</span><strong>Conditions dependencies and artifacts</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/01-runtime-expressions.html"><span>148.01</span><strong>Runtime expressions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/02-compile-time-expressions.html"><span>148.02</span><strong>Compile-time expressions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/03-conditions.html"><span>148.03</span><strong>Conditions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/04-output-variables.html"><span>148.04</span><strong>Output variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/05-job-dependencies.html"><span>148.05</span><strong>Job dependencies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/06-stage-dependencies.html"><span>148.06</span><strong>Stage dependencies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/07-artifact-download.html"><span>148.07</span><strong>Artifact download</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/08-pipeline-resources.html"><span>148.08</span><strong>Pipeline resources</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/09-multi-repository-checkout.html"><span>148.09</span><strong>Multi-repository checkout</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/148-conditions-dependencies-and-artifacts/10-orchestration-lab.html"><span>148.10</span><strong>Orchestration lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 149</span><strong>Secure production YAML</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/01-secret-variables.html"><span>149.01</span><strong>Secret variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/02-key-vault-integration.html"><span>149.02</span><strong>Key Vault integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/03-service-connections.html"><span>149.03</span><strong>Service connections</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/04-least-privilege.html"><span>149.04</span><strong>Least privilege</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/05-approval-checks.html"><span>149.05</span><strong>Approval checks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/06-policy-templates.html"><span>149.06</span><strong>Policy templates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/07-validation.html"><span>149.07</span><strong>Validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/08-testing-pipeline-changes.html"><span>149.08</span><strong>Testing pipeline changes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/09-documentation.html"><span>149.09</span><strong>Documentation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="yaml-pipelines/149-secure-production-yaml/10-yaml-capstone.html"><span>149.10</span><strong>YAML capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-devops-yaml-pipeline-development-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-devops-yaml-pipeline-development-catalog");
#   const search = document.getElementById("azure-devops-yaml-pipeline-development-catalog-search");
#   const empty = document.getElementById("azure-devops-yaml-pipeline-development-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **YAML Pipeline Development** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
