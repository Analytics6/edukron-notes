# %% [raw]
# ---
# title: "Linux & Shell Scripting"
# description: "Complete notebook syllabus for Linux & Shell Scripting in Azure DevOps."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>linux-shell-scripting.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure DevOps</span>
# <h1>Linux & Shell Scripting</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="linux-shell-scripting/131-linux-command-line-foundations/01-linux-filesystem.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Linux & Shell Scripting with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>5 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>3 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Linux command-line foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="linux-shell-scripting/131-linux-command-line-foundations/01-linux-filesystem.html">Linux filesystem</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="linux-shell-scripting/131-linux-command-line-foundations/10-command-line-practice-lab.html">Command-line practice lab</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Shell scripting foundations</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="linux-shell-scripting/132-shell-scripting-foundations/01-script-structure.html">Script structure</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="linux-shell-scripting/132-shell-scripting-foundations/10-automation-script-project.html">Automation-script project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Linux systems administration</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="linux-shell-scripting/133-linux-systems-administration/01-users-and-groups.html">Users and groups</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="linux-shell-scripting/133-linux-systems-administration/10-administration-lab.html">Administration lab</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Production shell automation</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="linux-shell-scripting/134-production-shell-automation/01-strict-mode.html">Strict mode</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="linux-shell-scripting/134-production-shell-automation/10-operations-capstone.html">Operations capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 05</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Linux & Shell Scripting outcome. Use <a href="linux-shell-scripting/134-production-shell-automation/10-operations-capstone.html">Operations capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure DevOps → Linux & Shell Scripting</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="131" href="linux-shell-scripting/131-linux-command-line-foundations/01-linux-filesystem.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 131</span><strong>Linux command-line foundations</strong><small>Enter with Linux filesystem. Demonstrate mastery through Command-line practice lab.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="132" href="linux-shell-scripting/132-shell-scripting-foundations/01-script-structure.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 132</span><strong>Shell scripting foundations</strong><small>Enter with Script structure. Demonstrate mastery through Automation-script project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="133" href="linux-shell-scripting/133-linux-systems-administration/01-users-and-groups.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 133</span><strong>Linux systems administration</strong><small>Enter with Users and groups. Demonstrate mastery through Administration lab.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="134" href="linux-shell-scripting/134-production-shell-automation/01-strict-mode.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 134</span><strong>Production shell automation</strong><small>Enter with Strict mode. Demonstrate mastery through Operations capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Linux & Shell Scripting workflow</strong><p>Combine evidence from every stage and finish with Operations capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-devops-linux-and-shell-scripting-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-devops-linux-and-shell-scripting-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Linux & Shell Scripting syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-devops-linux-and-shell-scripting-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 131</span><strong>Linux command-line foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/01-linux-filesystem.html"><span>131.01</span><strong>Linux filesystem</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/02-navigation-commands.html"><span>131.02</span><strong>Navigation commands</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/03-file-inspection.html"><span>131.03</span><strong>File inspection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/04-file-creation-and-removal.html"><span>131.04</span><strong>File creation and removal</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/05-copy-and-move-operations.html"><span>131.05</span><strong>Copy and move operations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/06-finding-files.html"><span>131.06</span><strong>Finding files</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/07-text-filters.html"><span>131.07</span><strong>Text filters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/08-pipes-and-redirection.html"><span>131.08</span><strong>Pipes and redirection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/09-help-and-documentation.html"><span>131.09</span><strong>Help and documentation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/131-linux-command-line-foundations/10-command-line-practice-lab.html"><span>131.10</span><strong>Command-line practice lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 132</span><strong>Shell scripting foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/01-script-structure.html"><span>132.01</span><strong>Script structure</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/02-variables.html"><span>132.02</span><strong>Variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/03-quoting.html"><span>132.03</span><strong>Quoting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/04-command-substitution.html"><span>132.04</span><strong>Command substitution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/05-conditionals.html"><span>132.05</span><strong>Conditionals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/06-loops.html"><span>132.06</span><strong>Loops</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/07-functions.html"><span>132.07</span><strong>Functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/08-exit-codes.html"><span>132.08</span><strong>Exit codes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/09-input-arguments.html"><span>132.09</span><strong>Input arguments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/132-shell-scripting-foundations/10-automation-script-project.html"><span>132.10</span><strong>Automation-script project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 133</span><strong>Linux systems administration</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/01-users-and-groups.html"><span>133.01</span><strong>Users and groups</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/02-file-permissions.html"><span>133.02</span><strong>File permissions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/03-processes.html"><span>133.03</span><strong>Processes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/04-signals.html"><span>133.04</span><strong>Signals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/05-services-with-systemd.html"><span>133.05</span><strong>Services with systemd</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/06-package-management.html"><span>133.06</span><strong>Package management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/07-environment-configuration.html"><span>133.07</span><strong>Environment configuration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/08-storage-inspection.html"><span>133.08</span><strong>Storage inspection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/09-network-diagnostics.html"><span>133.09</span><strong>Network diagnostics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/133-linux-systems-administration/10-administration-lab.html"><span>133.10</span><strong>Administration lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 134</span><strong>Production shell automation</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/01-strict-mode.html"><span>134.01</span><strong>Strict mode</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/02-error-handling.html"><span>134.02</span><strong>Error handling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/03-logging.html"><span>134.03</span><strong>Logging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/04-temporary-files.html"><span>134.04</span><strong>Temporary files</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/05-idempotent-scripts.html"><span>134.05</span><strong>Idempotent scripts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/06-configuration-files.html"><span>134.06</span><strong>Configuration files</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/07-secrets-handling.html"><span>134.07</span><strong>Secrets handling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/08-scheduled-jobs.html"><span>134.08</span><strong>Scheduled jobs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/09-shell-testing.html"><span>134.09</span><strong>Shell testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="linux-shell-scripting/134-production-shell-automation/10-operations-capstone.html"><span>134.10</span><strong>Operations capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-devops-linux-and-shell-scripting-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-devops-linux-and-shell-scripting-catalog");
#   const search = document.getElementById("azure-devops-linux-and-shell-scripting-catalog-search");
#   const empty = document.getElementById("azure-devops-linux-and-shell-scripting-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Linux & Shell Scripting** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
