# %% [raw]
# ---
# title: "Terraform Infrastructure as Code"
# description: "Complete notebook syllabus for Terraform Infrastructure as Code in Azure DevOps."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>terraform.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure DevOps</span>
# <h1>Terraform Infrastructure as Code</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="terraform/161-terraform-foundations/01-infrastructure-as-code.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-devops-terraform-infrastructure-as-code-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-devops-terraform-infrastructure-as-code-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Terraform Infrastructure as Code syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-devops-terraform-infrastructure-as-code-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 161</span><strong>Terraform foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/01-infrastructure-as-code.html"><span>161.01</span><strong>Infrastructure as Code</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/02-terraform-workflow.html"><span>161.02</span><strong>Terraform workflow</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/03-hcl-syntax.html"><span>161.03</span><strong>HCL syntax</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/04-providers.html"><span>161.04</span><strong>Providers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/05-resources.html"><span>161.05</span><strong>Resources</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/06-data-sources.html"><span>161.06</span><strong>Data sources</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/07-variables.html"><span>161.07</span><strong>Variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/08-outputs.html"><span>161.08</span><strong>Outputs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/09-plan-and-apply.html"><span>161.09</span><strong>Plan and apply</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/161-terraform-foundations/10-foundations-project.html"><span>161.10</span><strong>Foundations project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 162</span><strong>Provisioning Azure with Terraform</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/01-azure-provider.html"><span>162.01</span><strong>Azure provider</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/02-authentication.html"><span>162.02</span><strong>Authentication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/03-resource-groups.html"><span>162.03</span><strong>Resource groups</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/04-virtual-networks.html"><span>162.04</span><strong>Virtual networks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/05-storage-accounts.html"><span>162.05</span><strong>Storage accounts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/06-compute-resources.html"><span>162.06</span><strong>Compute resources</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/07-dependencies.html"><span>162.07</span><strong>Dependencies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/08-tags.html"><span>162.08</span><strong>Tags</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/09-naming-standards.html"><span>162.09</span><strong>Naming standards</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/162-provisioning-azure-with-terraform/10-azure-provisioning-project.html"><span>162.10</span><strong>Azure provisioning project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 163</span><strong>Terraform state and lifecycle</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/01-state-purpose.html"><span>163.01</span><strong>State purpose</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/02-remote-backends.html"><span>163.02</span><strong>Remote backends</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/03-state-locking.html"><span>163.03</span><strong>State locking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/04-state-commands.html"><span>163.04</span><strong>State commands</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/05-import.html"><span>163.05</span><strong>Import</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/06-moved-blocks.html"><span>163.06</span><strong>Moved blocks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/07-lifecycle-meta-arguments.html"><span>163.07</span><strong>Lifecycle meta-arguments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/08-drift-detection.html"><span>163.08</span><strong>Drift detection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/09-state-recovery.html"><span>163.09</span><strong>State recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/163-terraform-state-and-lifecycle/10-state-management-lab.html"><span>163.10</span><strong>State-management lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 164</span><strong>Modules testing and automation</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/01-module-design.html"><span>164.01</span><strong>Module design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/02-inputs-and-outputs.html"><span>164.02</span><strong>Inputs and outputs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/03-module-composition.html"><span>164.03</span><strong>Module composition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/04-version-constraints.html"><span>164.04</span><strong>Version constraints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/05-validation-rules.html"><span>164.05</span><strong>Validation rules</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/06-formatting-and-validation.html"><span>164.06</span><strong>Formatting and validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/07-plan-testing.html"><span>164.07</span><strong>Plan testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/08-policy-checks.html"><span>164.08</span><strong>Policy checks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/09-ci-integration.html"><span>164.09</span><strong>CI integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/164-modules-testing-and-automation/10-reusable-module-project.html"><span>164.10</span><strong>Reusable-module project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 165</span><strong>Production Terraform platforms</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/01-environment-strategy.html"><span>165.01</span><strong>Environment strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/02-workspace-tradeoffs.html"><span>165.02</span><strong>Workspace tradeoffs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/03-repository-layout.html"><span>165.03</span><strong>Repository layout</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/04-identity-and-secrets.html"><span>165.04</span><strong>Identity and secrets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/05-pipeline-approvals.html"><span>165.05</span><strong>Pipeline approvals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/06-safe-apply.html"><span>165.06</span><strong>Safe apply</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/07-observability.html"><span>165.07</span><strong>Observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/08-cost-estimation.html"><span>165.08</span><strong>Cost estimation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/09-disaster-recovery.html"><span>165.09</span><strong>Disaster recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="terraform/165-production-terraform-platforms/10-terraform-capstone.html"><span>165.10</span><strong>Terraform capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-devops-terraform-infrastructure-as-code-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-devops-terraform-infrastructure-as-code-catalog");
#   const search = document.getElementById("azure-devops-terraform-infrastructure-as-code-catalog-search");
#   const empty = document.getElementById("azure-devops-terraform-infrastructure-as-code-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Terraform Infrastructure as Code** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
