# %% [raw]
# ---
# title: "Azure Pipelines"
# description: "Complete notebook syllabus for Azure Pipelines in Azure DevOps."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>azure-pipelines.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure DevOps</span>
# <h1>Azure Pipelines</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="azure-pipelines/141-continuous-integration-foundations/01-ci-principles.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Azure Pipelines with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>6 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Continuous integration foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-pipelines/141-continuous-integration-foundations/01-ci-principles.html">CI principles</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-pipelines/141-continuous-integration-foundations/10-first-ci-pipeline.html">First CI pipeline</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Build and test automation</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-pipelines/142-build-and-test-automation/01-dependency-caching.html">Dependency caching</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-pipelines/142-build-and-test-automation/10-build-pipeline-project.html">Build-pipeline project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Continuous delivery and release</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-pipelines/143-continuous-delivery-and-release/01-cd-principles.html">CD principles</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-pipelines/143-continuous-delivery-and-release/10-delivery-pipeline-project.html">Delivery-pipeline project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Deployment strategies and environments</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-pipelines/144-deployment-strategies-and-environments/01-rolling-deployments.html">Rolling deployments</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-pipelines/144-deployment-strategies-and-environments/10-strategy-lab.html">Strategy lab</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Pipeline operations and governance</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-pipelines/145-pipeline-operations-and-governance/01-pipeline-permissions.html">Pipeline permissions</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-pipelines/145-pipeline-operations-and-governance/10-azure-pipelines-capstone.html">Azure Pipelines capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 06</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Azure Pipelines outcome. Use <a href="azure-pipelines/145-pipeline-operations-and-governance/10-azure-pipelines-capstone.html">Azure Pipelines capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure DevOps → Azure Pipelines</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="141" href="azure-pipelines/141-continuous-integration-foundations/01-ci-principles.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 141</span><strong>Continuous integration foundations</strong><small>Enter with CI principles. Demonstrate mastery through First CI pipeline.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="142" href="azure-pipelines/142-build-and-test-automation/01-dependency-caching.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 142</span><strong>Build and test automation</strong><small>Enter with Dependency caching. Demonstrate mastery through Build-pipeline project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="143" href="azure-pipelines/143-continuous-delivery-and-release/01-cd-principles.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 143</span><strong>Continuous delivery and release</strong><small>Enter with CD principles. Demonstrate mastery through Delivery-pipeline project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="144" href="azure-pipelines/144-deployment-strategies-and-environments/01-rolling-deployments.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 144</span><strong>Deployment strategies and environments</strong><small>Enter with Rolling deployments. Demonstrate mastery through Strategy lab.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="145" href="azure-pipelines/145-pipeline-operations-and-governance/01-pipeline-permissions.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 145</span><strong>Pipeline operations and governance</strong><small>Enter with Pipeline permissions. Demonstrate mastery through Azure Pipelines capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Azure Pipelines workflow</strong><p>Combine evidence from every stage and finish with Azure Pipelines capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-devops-azure-pipelines-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-devops-azure-pipelines-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Azure Pipelines syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-devops-azure-pipelines-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 141</span><strong>Continuous integration foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/01-ci-principles.html"><span>141.01</span><strong>CI principles</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/02-agents-and-pools.html"><span>141.02</span><strong>Agents and pools</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/03-pipeline-anatomy.html"><span>141.03</span><strong>Pipeline anatomy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/04-triggers.html"><span>141.04</span><strong>Triggers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/05-checkout.html"><span>141.05</span><strong>Checkout</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/06-build-stages.html"><span>141.06</span><strong>Build stages</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/07-test-stages.html"><span>141.07</span><strong>Test stages</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/08-artifacts.html"><span>141.08</span><strong>Artifacts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/09-pipeline-variables.html"><span>141.09</span><strong>Pipeline variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/141-continuous-integration-foundations/10-first-ci-pipeline.html"><span>141.10</span><strong>First CI pipeline</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 142</span><strong>Build and test automation</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/01-dependency-caching.html"><span>142.01</span><strong>Dependency caching</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/02-matrix-builds.html"><span>142.02</span><strong>Matrix builds</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/03-unit-tests.html"><span>142.03</span><strong>Unit tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/04-integration-tests.html"><span>142.04</span><strong>Integration tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/05-code-coverage.html"><span>142.05</span><strong>Code coverage</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/06-static-analysis.html"><span>142.06</span><strong>Static analysis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/07-package-creation.html"><span>142.07</span><strong>Package creation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/08-artifact-publishing.html"><span>142.08</span><strong>Artifact publishing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/09-quality-gates.html"><span>142.09</span><strong>Quality gates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/142-build-and-test-automation/10-build-pipeline-project.html"><span>142.10</span><strong>Build-pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 143</span><strong>Continuous delivery and release</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/01-cd-principles.html"><span>143.01</span><strong>CD principles</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/02-environments.html"><span>143.02</span><strong>Environments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/03-deployment-jobs.html"><span>143.03</span><strong>Deployment jobs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/04-service-connections.html"><span>143.04</span><strong>Service connections</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/05-secrets.html"><span>143.05</span><strong>Secrets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/06-approvals-and-checks.html"><span>143.06</span><strong>Approvals and checks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/07-release-artifacts.html"><span>143.07</span><strong>Release artifacts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/08-database-delivery.html"><span>143.08</span><strong>Database delivery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/09-rollback-design.html"><span>143.09</span><strong>Rollback design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/143-continuous-delivery-and-release/10-delivery-pipeline-project.html"><span>143.10</span><strong>Delivery-pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 144</span><strong>Deployment strategies and environments</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/01-rolling-deployments.html"><span>144.01</span><strong>Rolling deployments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/02-blue-green-deployments.html"><span>144.02</span><strong>Blue-green deployments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/03-canary-releases.html"><span>144.03</span><strong>Canary releases</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/04-feature-flags.html"><span>144.04</span><strong>Feature flags</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/05-ring-deployments.html"><span>144.05</span><strong>Ring deployments</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/06-environment-promotion.html"><span>144.06</span><strong>Environment promotion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/07-health-checks.html"><span>144.07</span><strong>Health checks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/08-automated-rollback.html"><span>144.08</span><strong>Automated rollback</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/09-release-evidence.html"><span>144.09</span><strong>Release evidence</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/144-deployment-strategies-and-environments/10-strategy-lab.html"><span>144.10</span><strong>Strategy lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 145</span><strong>Pipeline operations and governance</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/01-pipeline-permissions.html"><span>145.01</span><strong>Pipeline permissions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/02-variable-groups.html"><span>145.02</span><strong>Variable groups</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/03-secure-files.html"><span>145.03</span><strong>Secure files</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/04-retention.html"><span>145.04</span><strong>Retention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/05-concurrency.html"><span>145.05</span><strong>Concurrency</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/06-failure-diagnosis.html"><span>145.06</span><strong>Failure diagnosis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/07-reruns.html"><span>145.07</span><strong>Reruns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/08-cost-optimization.html"><span>145.08</span><strong>Cost optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/09-pipeline-analytics.html"><span>145.09</span><strong>Pipeline analytics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-pipelines/145-pipeline-operations-and-governance/10-azure-pipelines-capstone.html"><span>145.10</span><strong>Azure Pipelines capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-devops-azure-pipelines-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-devops-azure-pipelines-catalog");
#   const search = document.getElementById("azure-devops-azure-pipelines-catalog-search");
#   const empty = document.getElementById("azure-devops-azure-pipelines-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Azure Pipelines** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
