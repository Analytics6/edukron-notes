# %% [raw]
# ---
# title: "RAG"
# description: "Complete notebook syllabus for RAG in Full Stack AI."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>rag.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Full Stack AI</span>
# <h1>RAG</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="rag/067-rag-foundations/01-why-retrieval-is-needed.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="full-stack-ai-rag-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="full-stack-ai-rag-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the RAG syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="full-stack-ai-rag-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 067</span><strong>RAG foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="rag/067-rag-foundations/01-why-retrieval-is-needed.html"><span>067.01</span><strong>Why retrieval is needed</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/02-rag-architecture.html"><span>067.02</span><strong>RAG architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/03-knowledge-sources.html"><span>067.03</span><strong>Knowledge sources</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/04-indexing-lifecycle.html"><span>067.04</span><strong>Indexing lifecycle</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/05-query-lifecycle.html"><span>067.05</span><strong>Query lifecycle</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/06-retrieval-versus-fine-tuning.html"><span>067.06</span><strong>Retrieval versus fine-tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/07-grounded-generation.html"><span>067.07</span><strong>Grounded generation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/08-citations.html"><span>067.08</span><strong>Citations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/09-rag-failure-modes.html"><span>067.09</span><strong>RAG failure modes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/067-rag-foundations/10-first-rag-system.html"><span>067.10</span><strong>First RAG system</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 068</span><strong>Document ingestion and chunking</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/01-document-loaders.html"><span>068.01</span><strong>Document loaders</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/02-pdf-extraction.html"><span>068.02</span><strong>PDF extraction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/03-html-extraction.html"><span>068.03</span><strong>HTML extraction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/04-metadata-design.html"><span>068.04</span><strong>Metadata design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/05-text-cleaning.html"><span>068.05</span><strong>Text cleaning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/06-fixed-size-chunking.html"><span>068.06</span><strong>Fixed-size chunking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/07-semantic-chunking.html"><span>068.07</span><strong>Semantic chunking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/08-parent-child-chunking.html"><span>068.08</span><strong>Parent-child chunking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/09-ingestion-validation.html"><span>068.09</span><strong>Ingestion validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/068-document-ingestion-and-chunking/10-ingestion-pipeline-project.html"><span>068.10</span><strong>Ingestion pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 069</span><strong>Embeddings and vector stores</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/01-embedding-models.html"><span>069.01</span><strong>Embedding models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/02-dense-vectors.html"><span>069.02</span><strong>Dense vectors</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/03-similarity-search.html"><span>069.03</span><strong>Similarity search</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/04-vector-indexing.html"><span>069.04</span><strong>Vector indexing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/05-vector-databases.html"><span>069.05</span><strong>Vector databases</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/06-metadata-filtering.html"><span>069.06</span><strong>Metadata filtering</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/07-namespace-design.html"><span>069.07</span><strong>Namespace design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/08-index-updates.html"><span>069.08</span><strong>Index updates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/09-embedding-evaluation.html"><span>069.09</span><strong>Embedding evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/069-embeddings-and-vector-stores/10-vector-store-project.html"><span>069.10</span><strong>Vector-store project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 070</span><strong>Retrieval and reranking</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/01-dense-retrieval.html"><span>070.01</span><strong>Dense retrieval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/02-sparse-retrieval.html"><span>070.02</span><strong>Sparse retrieval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/03-bm25.html"><span>070.03</span><strong>BM25</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/04-hybrid-search.html"><span>070.04</span><strong>Hybrid search</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/05-query-rewriting.html"><span>070.05</span><strong>Query rewriting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/06-multi-query-retrieval.html"><span>070.06</span><strong>Multi-query retrieval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/07-reranking.html"><span>070.07</span><strong>Reranking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/08-context-compression.html"><span>070.08</span><strong>Context compression</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/09-retrieval-metrics.html"><span>070.09</span><strong>Retrieval metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/070-retrieval-and-reranking/10-retrieval-benchmark.html"><span>070.10</span><strong>Retrieval benchmark</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 071</span><strong>RAG generation and evaluation</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/01-context-assembly.html"><span>071.01</span><strong>Context assembly</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/02-grounding-prompts.html"><span>071.02</span><strong>Grounding prompts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/03-citation-generation.html"><span>071.03</span><strong>Citation generation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/04-abstention.html"><span>071.04</span><strong>Abstention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/05-answer-relevance.html"><span>071.05</span><strong>Answer relevance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/06-context-relevance.html"><span>071.06</span><strong>Context relevance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/07-faithfulness.html"><span>071.07</span><strong>Faithfulness</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/08-end-to-end-evaluation.html"><span>071.08</span><strong>End-to-end evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/09-error-analysis.html"><span>071.09</span><strong>Error analysis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/071-rag-generation-and-evaluation/10-rag-evaluation-project.html"><span>071.10</span><strong>RAG evaluation project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 072</span><strong>Advanced production RAG</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/01-conversational-rag.html"><span>072.01</span><strong>Conversational RAG</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/02-graph-rag.html"><span>072.02</span><strong>Graph RAG</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/03-multimodal-rag.html"><span>072.03</span><strong>Multimodal RAG</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/04-agentic-retrieval.html"><span>072.04</span><strong>Agentic retrieval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/05-access-controlled-retrieval.html"><span>072.05</span><strong>Access-controlled retrieval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/06-caching.html"><span>072.06</span><strong>Caching</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/07-observability.html"><span>072.07</span><strong>Observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/08-scaling.html"><span>072.08</span><strong>Scaling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/09-security.html"><span>072.09</span><strong>Security</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="rag/072-advanced-production-rag/10-production-rag-capstone.html"><span>072.10</span><strong>Production-RAG capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="full-stack-ai-rag-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("full-stack-ai-rag-catalog");
#   const search = document.getElementById("full-stack-ai-rag-catalog-search");
#   const empty = document.getElementById("full-stack-ai-rag-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **RAG** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
