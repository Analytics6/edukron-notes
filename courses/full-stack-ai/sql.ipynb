# %% [raw]
# ---
# title: "SQL"
# description: "Complete notebook syllabus for SQL in Full Stack AI."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>sql.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Full Stack AI</span>
# <h1>SQL</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="sql/011-relational-database-foundations/01-databases-and-rdbms-concepts.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="full-stack-ai-sql-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="full-stack-ai-sql-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the SQL syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="full-stack-ai-sql-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 011</span><strong>Relational database foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/01-databases-and-rdbms-concepts.html"><span>011.01</span><strong>Databases and RDBMS concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/02-tables-rows-and-columns.html"><span>011.02</span><strong>Tables rows and columns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/03-keys-and-relationships.html"><span>011.03</span><strong>Keys and relationships</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/04-sql-data-types.html"><span>011.04</span><strong>SQL data types</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/05-creating-databases.html"><span>011.05</span><strong>Creating databases</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/06-creating-tables.html"><span>011.06</span><strong>Creating tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/07-altering-tables.html"><span>011.07</span><strong>Altering tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/08-inserting-data.html"><span>011.08</span><strong>Inserting data</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/09-updating-and-deleting.html"><span>011.09</span><strong>Updating and deleting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/011-relational-database-foundations/10-database-foundations-lab.html"><span>011.10</span><strong>Database foundations lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 012</span><strong>SQL querying fundamentals</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/01-select-statements.html"><span>012.01</span><strong>SELECT statements</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/02-column-aliases.html"><span>012.02</span><strong>Column aliases</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/03-distinct.html"><span>012.03</span><strong>DISTINCT</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/04-where-filtering.html"><span>012.04</span><strong>WHERE filtering</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/05-comparison-operators.html"><span>012.05</span><strong>Comparison operators</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/06-logical-operators.html"><span>012.06</span><strong>Logical operators</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/07-null-handling.html"><span>012.07</span><strong>NULL handling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/08-sorting-results.html"><span>012.08</span><strong>Sorting results</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/09-limiting-results.html"><span>012.09</span><strong>Limiting results</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/012-sql-querying-fundamentals/10-querying-practice-set.html"><span>012.10</span><strong>Querying practice set</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 013</span><strong>Joins and set operations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/01-inner-join.html"><span>013.01</span><strong>INNER JOIN</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/02-left-join.html"><span>013.02</span><strong>LEFT JOIN</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/03-right-and-full-join.html"><span>013.03</span><strong>RIGHT and FULL JOIN</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/04-self-joins.html"><span>013.04</span><strong>Self joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/05-cross-joins.html"><span>013.05</span><strong>Cross joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/06-multi-table-joins.html"><span>013.06</span><strong>Multi-table joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/07-union-and-union-all.html"><span>013.07</span><strong>UNION and UNION ALL</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/08-intersect-and-except.html"><span>013.08</span><strong>INTERSECT and EXCEPT</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/09-join-troubleshooting.html"><span>013.09</span><strong>Join troubleshooting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/013-joins-and-set-operations/10-multi-table-project.html"><span>013.10</span><strong>Multi-table project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 014</span><strong>Aggregations and analytical SQL</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/01-aggregate-functions.html"><span>014.01</span><strong>Aggregate functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/02-group-by.html"><span>014.02</span><strong>GROUP BY</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/03-having.html"><span>014.03</span><strong>HAVING</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/04-conditional-aggregation.html"><span>014.04</span><strong>Conditional aggregation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/05-case-expressions.html"><span>014.05</span><strong>CASE expressions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/06-window-function-foundations.html"><span>014.06</span><strong>Window-function foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/07-ranking-functions.html"><span>014.07</span><strong>Ranking functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/08-running-totals.html"><span>014.08</span><strong>Running totals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/09-lag-and-lead.html"><span>014.09</span><strong>Lag and lead</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/014-aggregations-and-analytical-sql/10-analytics-project.html"><span>014.10</span><strong>Analytics project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 015</span><strong>Database design and integrity</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/01-data-modeling.html"><span>015.01</span><strong>Data modeling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/02-normalization.html"><span>015.02</span><strong>Normalization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/03-denormalization.html"><span>015.03</span><strong>Denormalization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/04-primary-and-foreign-keys.html"><span>015.04</span><strong>Primary and foreign keys</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/05-unique-constraints.html"><span>015.05</span><strong>Unique constraints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/06-check-constraints.html"><span>015.06</span><strong>Check constraints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/07-index-foundations.html"><span>015.07</span><strong>Index foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/08-views.html"><span>015.08</span><strong>Views</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/09-stored-procedures-and-functions.html"><span>015.09</span><strong>Stored procedures and functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/015-database-design-and-integrity/10-database-design-project.html"><span>015.10</span><strong>Database-design project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 016</span><strong>SQL performance and transactions</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/01-execution-plans.html"><span>016.01</span><strong>Execution plans</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/02-index-selection.html"><span>016.02</span><strong>Index selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/03-sargable-predicates.html"><span>016.03</span><strong>Sargable predicates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/04-join-performance.html"><span>016.04</span><strong>Join performance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/05-query-refactoring.html"><span>016.05</span><strong>Query refactoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/06-transactions.html"><span>016.06</span><strong>Transactions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/07-acid-properties.html"><span>016.07</span><strong>ACID properties</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/08-locks-and-isolation.html"><span>016.08</span><strong>Locks and isolation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/09-deadlocks-and-recovery.html"><span>016.09</span><strong>Deadlocks and recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/016-sql-performance-and-transactions/10-performance-lab.html"><span>016.10</span><strong>Performance lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 017</span><strong>SQL for analytics and AI</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/01-data-cleaning-sql.html"><span>017.01</span><strong>Data-cleaning SQL</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/02-feature-table-creation.html"><span>017.02</span><strong>Feature-table creation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/03-time-series-sql.html"><span>017.03</span><strong>Time-series SQL</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/04-cohort-analysis.html"><span>017.04</span><strong>Cohort analysis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/05-funnel-analysis.html"><span>017.05</span><strong>Funnel analysis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/06-customer-segmentation.html"><span>017.06</span><strong>Customer segmentation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/07-data-quality-checks.html"><span>017.07</span><strong>Data-quality checks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/08-incremental-transformations.html"><span>017.08</span><strong>Incremental transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/09-sql-testing.html"><span>017.09</span><strong>SQL testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/017-sql-for-analytics-and-ai/10-analytics-capstone.html"><span>017.10</span><strong>Analytics capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="full-stack-ai-sql-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("full-stack-ai-sql-catalog");
#   const search = document.getElementById("full-stack-ai-sql-catalog-search");
#   const empty = document.getElementById("full-stack-ai-sql-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **SQL** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
