# %% [raw]
# ---
# title: "Full Stack AI — Overview"
# description: "A complete path from programming and data foundations to production-ready generative and agentic AI systems."
# author: "Edukron Notes"
# date: "2026-09-09"
# categories: [program-overview, full-stack-ai]
# toc: true
# page-layout: article
# execute: false
# ---

# %% [markdown]
# <section class="program-intro">
#   <div class="overview-lead">
#     <span class="topic-icon"><i class="bi bi-cpu" aria-hidden="true"></i></span>
#     <div><span class="overview-eyebrow">Learning path</span><p>A complete path from programming and data foundations to production-ready generative and agentic AI systems.</p></div>
#   </div>
# </section>
#
# ::: {.callout-tip}
# ### Course map
# Each subject has a dedicated overview. Detailed notebooks are added in the approved learning sequence.
# :::

# %% [markdown]
# ## Choose an overview
#
# <div class="feature-grid curriculum-grid">
#   <a class="course-card" href="python.html"><span class="card-icon"><i class="bi bi-code-square" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Python</strong><span>Programming foundations for data, automation, APIs, and AI applications.</span></a>
#   <a class="course-card" href="sql.html"><span class="card-icon"><i class="bi bi-database" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>SQL</strong><span>Querying, transforming, and validating relational data for analytics and AI.</span></a>
#   <a class="course-card" href="data-science.html"><span class="card-icon"><i class="bi bi-bar-chart-line" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Data Science</strong><span>A reproducible workflow for cleaning, exploring, visualizing, and explaining data.</span></a>
#   <a class="course-card" href="machine-learning.html"><span class="card-icon"><i class="bi bi-diagram-3" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Machine Learning</strong><span>Model training, evaluation, feature workflows, and responsible prediction.</span></a>
#   <a class="course-card" href="artificial-intelligence.html"><span class="card-icon"><i class="bi bi-robot" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Artificial Intelligence</strong><span>Search, reasoning, knowledge representation, planning, and intelligent systems.</span></a>
#   <a class="course-card" href="deep-learning.html"><span class="card-icon"><i class="bi bi-cpu" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Deep Learning</strong><span>Neural networks, representation learning, optimization, and modern architectures.</span></a>
#   <a class="course-card" href="generative-ai.html"><span class="card-icon"><i class="bi bi-stars" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Generative AI</strong><span>Building and evaluating systems that generate text and other useful outputs.</span></a>
#   <a class="course-card" href="large-language-models.html"><span class="card-icon"><i class="bi bi-chat-square-text" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Large Language Models (LLMs)</strong><span>Tokens, transformers, prompting, adaptation, inference, and evaluation.</span></a>
#   <a class="course-card" href="rag.html"><span class="card-icon"><i class="bi bi-search" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Retrieval Augmented Generation (RAG)</strong><span>Grounding model responses in retrieved, traceable knowledge.</span></a>
#   <a class="course-card" href="agentic-ai.html"><span class="card-icon"><i class="bi bi-node-plus" aria-hidden="true"></i></span><span class="course-number">Overview</span><strong>Agentic AI</strong><span>Tool-using AI systems with planning, memory, guardrails, and observability.</span></a>
# </div>

# %% [markdown]
# ## Publishing standard
#
# All material in this section will remain notebook-first: white reading surfaces, clear explanations, runnable or copy-ready examples where appropriate, visible outputs, exercises, and concise recaps. Each approved module will receive its own Jupyter notebook and a stable place in this course map.
