# %% [raw]
# ---
# title: "Large Language Models"
# description: "Complete notebook syllabus for Large Language Models in Full Stack AI."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>large-language-models.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Full Stack AI</span>
# <h1>Large Language Models</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="large-language-models/059-tokenization-and-embeddings/01-text-tokenization.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="full-stack-ai-large-language-models-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="full-stack-ai-large-language-models-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Large Language Models syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="full-stack-ai-large-language-models-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 059</span><strong>Tokenization and embeddings</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/01-text-tokenization.html"><span>059.01</span><strong>Text tokenization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/02-subword-algorithms.html"><span>059.02</span><strong>Subword algorithms</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/03-vocabulary-construction.html"><span>059.03</span><strong>Vocabulary construction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/04-token-ids.html"><span>059.04</span><strong>Token IDs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/05-context-windows.html"><span>059.05</span><strong>Context windows</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/06-word-embeddings.html"><span>059.06</span><strong>Word embeddings</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/07-sentence-embeddings.html"><span>059.07</span><strong>Sentence embeddings</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/08-similarity-metrics.html"><span>059.08</span><strong>Similarity metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/09-embedding-evaluation.html"><span>059.09</span><strong>Embedding evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/059-tokenization-and-embeddings/10-embedding-project.html"><span>059.10</span><strong>Embedding project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 060</span><strong>Transformer internals</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/01-transformer-architecture.html"><span>060.01</span><strong>Transformer architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/02-self-attention-mathematics.html"><span>060.02</span><strong>Self-attention mathematics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/03-multi-head-attention.html"><span>060.03</span><strong>Multi-head attention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/04-feed-forward-layers.html"><span>060.04</span><strong>Feed-forward layers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/05-residual-connections.html"><span>060.05</span><strong>Residual connections</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/06-layer-normalization.html"><span>060.06</span><strong>Layer normalization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/07-positional-information.html"><span>060.07</span><strong>Positional information</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/08-causal-masking.html"><span>060.08</span><strong>Causal masking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/09-training-objectives.html"><span>060.09</span><strong>Training objectives</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/060-transformer-internals/10-mini-transformer-implementation.html"><span>060.10</span><strong>Mini-transformer implementation</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 061</span><strong>Advanced LLM prompting</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/01-system-instructions.html"><span>061.01</span><strong>System instructions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/02-context-management.html"><span>061.02</span><strong>Context management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/03-few-shot-examples.html"><span>061.03</span><strong>Few-shot examples</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/04-reasoning-strategies.html"><span>061.04</span><strong>Reasoning strategies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/05-decomposition.html"><span>061.05</span><strong>Decomposition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/06-self-consistency.html"><span>061.06</span><strong>Self-consistency</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/07-structured-output.html"><span>061.07</span><strong>Structured output</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/08-tool-selection-prompts.html"><span>061.08</span><strong>Tool-selection prompts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/09-prompt-versioning.html"><span>061.09</span><strong>Prompt versioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/061-advanced-llm-prompting/10-prompt-system-project.html"><span>061.10</span><strong>Prompt-system project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 062</span><strong>LLM adaptation</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/01-fine-tuning-foundations.html"><span>062.01</span><strong>Fine-tuning foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/02-dataset-preparation.html"><span>062.02</span><strong>Dataset preparation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/03-supervised-fine-tuning.html"><span>062.03</span><strong>Supervised fine-tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/04-lora.html"><span>062.04</span><strong>LoRA</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/05-quantized-lora.html"><span>062.05</span><strong>Quantized LoRA</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/06-preference-datasets.html"><span>062.06</span><strong>Preference datasets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/07-dpo-concepts.html"><span>062.07</span><strong>DPO concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/08-model-merging.html"><span>062.08</span><strong>Model merging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/09-adaptation-evaluation.html"><span>062.09</span><strong>Adaptation evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/062-llm-adaptation/10-fine-tuning-project.html"><span>062.10</span><strong>Fine-tuning project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 063</span><strong>LLM inference and optimization</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/01-decoding-strategies.html"><span>063.01</span><strong>Decoding strategies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/02-kv-cache.html"><span>063.02</span><strong>KV cache</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/03-batching.html"><span>063.03</span><strong>Batching</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/04-quantization.html"><span>063.04</span><strong>Quantization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/05-distillation.html"><span>063.05</span><strong>Distillation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/06-speculative-decoding.html"><span>063.06</span><strong>Speculative decoding</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/07-model-routing.html"><span>063.07</span><strong>Model routing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/08-latency-measurement.html"><span>063.08</span><strong>Latency measurement</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/09-cost-optimization.html"><span>063.09</span><strong>Cost optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/063-llm-inference-and-optimization/10-inference-benchmark.html"><span>063.10</span><strong>Inference benchmark</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 064</span><strong>LLM evaluation and safety</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/01-evaluation-datasets.html"><span>064.01</span><strong>Evaluation datasets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/02-task-metrics.html"><span>064.02</span><strong>Task metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/03-factuality.html"><span>064.03</span><strong>Factuality</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/04-relevance.html"><span>064.04</span><strong>Relevance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/05-groundedness.html"><span>064.05</span><strong>Groundedness</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/06-bias-evaluation.html"><span>064.06</span><strong>Bias evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/07-toxicity-evaluation.html"><span>064.07</span><strong>Toxicity evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/08-jailbreak-testing.html"><span>064.08</span><strong>Jailbreak testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/09-human-review-design.html"><span>064.09</span><strong>Human-review design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/064-llm-evaluation-and-safety/10-llm-safety-report.html"><span>064.10</span><strong>LLM safety report</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 065</span><strong>LLM application engineering</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/01-chat-architecture.html"><span>065.01</span><strong>Chat architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/02-conversation-memory.html"><span>065.02</span><strong>Conversation memory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/03-structured-extraction.html"><span>065.03</span><strong>Structured extraction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/04-tool-calling.html"><span>065.04</span><strong>Tool calling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/05-retrieval-integration.html"><span>065.05</span><strong>Retrieval integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/06-response-streaming.html"><span>065.06</span><strong>Response streaming</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/07-guardrails.html"><span>065.07</span><strong>Guardrails</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/08-testing.html"><span>065.08</span><strong>Testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/09-observability.html"><span>065.09</span><strong>Observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/065-llm-application-engineering/10-llm-application-project.html"><span>065.10</span><strong>LLM application project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 066</span><strong>LLMOps and production systems</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/01-model-gateways.html"><span>066.01</span><strong>Model gateways</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/02-prompt-registries.html"><span>066.02</span><strong>Prompt registries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/03-evaluation-pipelines.html"><span>066.03</span><strong>Evaluation pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/04-deployment-strategies.html"><span>066.04</span><strong>Deployment strategies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/05-rate-limiting.html"><span>066.05</span><strong>Rate limiting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/06-caching.html"><span>066.06</span><strong>Caching</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/07-tracing.html"><span>066.07</span><strong>Tracing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/08-feedback-collection.html"><span>066.08</span><strong>Feedback collection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/09-governance.html"><span>066.09</span><strong>Governance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="large-language-models/066-llmops-and-production-systems/10-production-llm-capstone.html"><span>066.10</span><strong>Production-LLM capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="full-stack-ai-large-language-models-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("full-stack-ai-large-language-models-catalog");
#   const search = document.getElementById("full-stack-ai-large-language-models-catalog-search");
#   const empty = document.getElementById("full-stack-ai-large-language-models-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Large Language Models** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
