# %% [raw]
# ---
# title: "Agentic AI"
# description: "Complete notebook syllabus for Agentic AI in Full Stack AI."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>agentic-ai.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Full Stack AI</span>
# <h1>Agentic AI</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="agentic-ai/073-agentic-ai-foundations/01-agents-versus-workflows.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Agentic AI with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>9 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>5 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Agentic-AI foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/073-agentic-ai-foundations/01-agents-versus-workflows.html">Agents versus workflows</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/073-agentic-ai-foundations/10-first-agent.html">First agent</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Tools and function calling</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/074-tools-and-function-calling/01-tool-definitions.html">Tool definitions</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/074-tools-and-function-calling/10-tool-using-agent-project.html">Tool-using agent project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Planning and reasoning</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/075-planning-and-reasoning/01-task-decomposition.html">Task decomposition</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/075-planning-and-reasoning/10-planning-agent-project.html">Planning-agent project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Agent memory and state</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/076-agent-memory-and-state/01-conversation-state.html">Conversation state</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/076-agent-memory-and-state/10-stateful-agent-project.html">Stateful-agent project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Multi-agent systems</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/077-multi-agent-systems/01-multi-agent-foundations.html">Multi-agent foundations</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/077-multi-agent-systems/10-multi-agent-project.html">Multi-agent project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 06</span><strong>Agent security and guardrails</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/078-agent-security-and-guardrails/01-prompt-injection.html">Prompt injection</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/078-agent-security-and-guardrails/10-secure-agent-project.html">Secure-agent project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 07</span><strong>Agent evaluation and observability</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/079-agent-evaluation-and-observability/01-success-criteria.html">Success criteria</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/079-agent-evaluation-and-observability/10-agent-evaluation-system.html">Agent-evaluation system</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 08</span><strong>Production agentic systems</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="agentic-ai/080-production-agentic-systems/01-agent-architecture.html">Agent architecture</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="agentic-ai/080-production-agentic-systems/10-agentic-ai-capstone.html">Agentic-AI capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 09</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Agentic AI outcome. Use <a href="agentic-ai/080-production-agentic-systems/10-agentic-ai-capstone.html">Agentic-AI capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Full Stack AI → Agentic AI</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="073" href="agentic-ai/073-agentic-ai-foundations/01-agents-versus-workflows.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 073</span><strong>Agentic-AI foundations</strong><small>Enter with Agents versus workflows. Demonstrate mastery through First agent.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="074" href="agentic-ai/074-tools-and-function-calling/01-tool-definitions.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 074</span><strong>Tools and function calling</strong><small>Enter with Tool definitions. Demonstrate mastery through Tool-using agent project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="075" href="agentic-ai/075-planning-and-reasoning/01-task-decomposition.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 075</span><strong>Planning and reasoning</strong><small>Enter with Task decomposition. Demonstrate mastery through Planning-agent project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="076" href="agentic-ai/076-agent-memory-and-state/01-conversation-state.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 076</span><strong>Agent memory and state</strong><small>Enter with Conversation state. Demonstrate mastery through Stateful-agent project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="077" href="agentic-ai/077-multi-agent-systems/01-multi-agent-foundations.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 077</span><strong>Multi-agent systems</strong><small>Enter with Multi-agent foundations. Demonstrate mastery through Multi-agent project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="078" href="agentic-ai/078-agent-security-and-guardrails/01-prompt-injection.html">
# <span class="path-index">06</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 078</span><strong>Agent security and guardrails</strong><small>Enter with Prompt injection. Demonstrate mastery through Secure-agent project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="079" href="agentic-ai/079-agent-evaluation-and-observability/01-success-criteria.html">
# <span class="path-index">07</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 079</span><strong>Agent evaluation and observability</strong><small>Enter with Success criteria. Demonstrate mastery through Agent-evaluation system.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="080" href="agentic-ai/080-production-agentic-systems/01-agent-architecture.html">
# <span class="path-index">08</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 080</span><strong>Production agentic systems</strong><small>Enter with Agent architecture. Demonstrate mastery through Agentic-AI capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Agentic AI workflow</strong><p>Combine evidence from every stage and finish with Agentic-AI capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="full-stack-ai-agentic-ai-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="full-stack-ai-agentic-ai-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Agentic AI syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="full-stack-ai-agentic-ai-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 073</span><strong>Agentic-AI foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/01-agents-versus-workflows.html"><span>073.01</span><strong>Agents versus workflows</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/02-agent-components.html"><span>073.02</span><strong>Agent components</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/03-goals-and-tasks.html"><span>073.03</span><strong>Goals and tasks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/04-environment-modeling.html"><span>073.04</span><strong>Environment modeling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/05-actions-and-observations.html"><span>073.05</span><strong>Actions and observations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/06-agent-loops.html"><span>073.06</span><strong>Agent loops</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/07-deterministic-workflows.html"><span>073.07</span><strong>Deterministic workflows</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/08-autonomy-levels.html"><span>073.08</span><strong>Autonomy levels</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/09-failure-modes.html"><span>073.09</span><strong>Failure modes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/073-agentic-ai-foundations/10-first-agent.html"><span>073.10</span><strong>First agent</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 074</span><strong>Tools and function calling</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/01-tool-definitions.html"><span>074.01</span><strong>Tool definitions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/02-json-schemas.html"><span>074.02</span><strong>JSON schemas</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/03-tool-selection.html"><span>074.03</span><strong>Tool selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/04-argument-validation.html"><span>074.04</span><strong>Argument validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/05-tool-execution.html"><span>074.05</span><strong>Tool execution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/06-error-handling.html"><span>074.06</span><strong>Error handling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/07-tool-permissions.html"><span>074.07</span><strong>Tool permissions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/08-parallel-tools.html"><span>074.08</span><strong>Parallel tools</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/09-tool-result-grounding.html"><span>074.09</span><strong>Tool-result grounding</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/074-tools-and-function-calling/10-tool-using-agent-project.html"><span>074.10</span><strong>Tool-using agent project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 075</span><strong>Planning and reasoning</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/01-task-decomposition.html"><span>075.01</span><strong>Task decomposition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/02-plan-generation.html"><span>075.02</span><strong>Plan generation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/03-react-pattern.html"><span>075.03</span><strong>ReAct pattern</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/04-plan-and-execute.html"><span>075.04</span><strong>Plan-and-execute</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/05-reflection.html"><span>075.05</span><strong>Reflection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/06-self-correction.html"><span>075.06</span><strong>Self-correction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/07-search-based-planning.html"><span>075.07</span><strong>Search-based planning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/08-budget-aware-planning.html"><span>075.08</span><strong>Budget-aware planning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/09-plan-evaluation.html"><span>075.09</span><strong>Plan evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/075-planning-and-reasoning/10-planning-agent-project.html"><span>075.10</span><strong>Planning-agent project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 076</span><strong>Agent memory and state</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/01-conversation-state.html"><span>076.01</span><strong>Conversation state</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/02-working-memory.html"><span>076.02</span><strong>Working memory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/03-long-term-memory.html"><span>076.03</span><strong>Long-term memory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/04-episodic-memory.html"><span>076.04</span><strong>Episodic memory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/05-semantic-memory.html"><span>076.05</span><strong>Semantic memory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/06-memory-retrieval.html"><span>076.06</span><strong>Memory retrieval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/07-memory-summarization.html"><span>076.07</span><strong>Memory summarization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/08-state-machines.html"><span>076.08</span><strong>State machines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/09-privacy-and-retention.html"><span>076.09</span><strong>Privacy and retention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/076-agent-memory-and-state/10-stateful-agent-project.html"><span>076.10</span><strong>Stateful-agent project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 077</span><strong>Multi-agent systems</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/01-multi-agent-foundations.html"><span>077.01</span><strong>Multi-agent foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/02-agent-roles.html"><span>077.02</span><strong>Agent roles</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/03-delegation.html"><span>077.03</span><strong>Delegation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/04-handoffs.html"><span>077.04</span><strong>Handoffs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/05-shared-state.html"><span>077.05</span><strong>Shared state</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/06-debate-patterns.html"><span>077.06</span><strong>Debate patterns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/07-supervisor-patterns.html"><span>077.07</span><strong>Supervisor patterns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/08-coordination-failures.html"><span>077.08</span><strong>Coordination failures</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/09-multi-agent-evaluation.html"><span>077.09</span><strong>Multi-agent evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/077-multi-agent-systems/10-multi-agent-project.html"><span>077.10</span><strong>Multi-agent project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 078</span><strong>Agent security and guardrails</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/01-prompt-injection.html"><span>078.01</span><strong>Prompt injection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/02-tool-abuse.html"><span>078.02</span><strong>Tool abuse</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/03-least-privilege.html"><span>078.03</span><strong>Least privilege</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/04-sandboxing.html"><span>078.04</span><strong>Sandboxing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/05-human-approval.html"><span>078.05</span><strong>Human approval</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/06-input-validation.html"><span>078.06</span><strong>Input validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/07-output-validation.html"><span>078.07</span><strong>Output validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/08-policy-enforcement.html"><span>078.08</span><strong>Policy enforcement</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/09-incident-handling.html"><span>078.09</span><strong>Incident handling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/078-agent-security-and-guardrails/10-secure-agent-project.html"><span>078.10</span><strong>Secure-agent project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 079</span><strong>Agent evaluation and observability</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/01-success-criteria.html"><span>079.01</span><strong>Success criteria</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/02-trajectory-evaluation.html"><span>079.02</span><strong>Trajectory evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/03-tool-call-evaluation.html"><span>079.03</span><strong>Tool-call evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/04-planning-evaluation.html"><span>079.04</span><strong>Planning evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/05-cost-and-latency.html"><span>079.05</span><strong>Cost and latency</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/06-tracing.html"><span>079.06</span><strong>Tracing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/07-failure-classification.html"><span>079.07</span><strong>Failure classification</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/08-regression-suites.html"><span>079.08</span><strong>Regression suites</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/09-human-evaluation.html"><span>079.09</span><strong>Human evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/079-agent-evaluation-and-observability/10-agent-evaluation-system.html"><span>079.10</span><strong>Agent-evaluation system</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 080</span><strong>Production agentic systems</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/01-agent-architecture.html"><span>080.01</span><strong>Agent architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/02-durable-execution.html"><span>080.02</span><strong>Durable execution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/03-queues-and-scheduling.html"><span>080.03</span><strong>Queues and scheduling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/04-retry-policies.html"><span>080.04</span><strong>Retry policies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/05-state-persistence.html"><span>080.05</span><strong>State persistence</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/06-monitoring.html"><span>080.06</span><strong>Monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/07-cost-governance.html"><span>080.07</span><strong>Cost governance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/08-deployment.html"><span>080.08</span><strong>Deployment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/09-operational-runbooks.html"><span>080.09</span><strong>Operational runbooks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="agentic-ai/080-production-agentic-systems/10-agentic-ai-capstone.html"><span>080.10</span><strong>Agentic-AI capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="full-stack-ai-agentic-ai-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("full-stack-ai-agentic-ai-catalog");
#   const search = document.getElementById("full-stack-ai-agentic-ai-catalog-search");
#   const empty = document.getElementById("full-stack-ai-agentic-ai-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Agentic AI** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
