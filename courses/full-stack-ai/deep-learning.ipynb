# %% [raw]
# ---
# title: "Deep Learning"
# description: "Complete notebook syllabus for Deep Learning in Full Stack AI."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>deep-learning.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Full Stack AI</span>
# <h1>Deep Learning</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="deep-learning/044-neural-network-foundations/01-neurons-and-layers.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Deep Learning with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>9 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>5 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Neural-network foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/044-neural-network-foundations/01-neurons-and-layers.html">Neurons and layers</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/044-neural-network-foundations/10-neural-network-project.html">Neural-network project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Deep-learning optimization</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/045-deep-learning-optimization/01-gradient-descent-review.html">Gradient-descent review</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/045-deep-learning-optimization/10-optimization-experiment.html">Optimization experiment</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Convolutional neural networks</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/046-convolutional-neural-networks/01-image-tensors.html">Image tensors</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/046-convolutional-neural-networks/10-image-classification-project.html">Image-classification project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Sequence models</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/047-sequence-models/01-sequential-data.html">Sequential data</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/047-sequence-models/10-sequence-model-project.html">Sequence-model project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Attention and transformers</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/048-attention-and-transformers/01-attention-intuition.html">Attention intuition</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/048-attention-and-transformers/10-transformer-project.html">Transformer project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 06</span><strong>Autoencoders and generative deep learning</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/049-autoencoders-and-generative-deep-learning/01-autoencoders.html">Autoencoders</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/049-autoencoders-and-generative-deep-learning/10-generative-project.html">Generative project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 07</span><strong>Deep-learning engineering</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/050-deep-learning-engineering/01-dataset-pipelines.html">Dataset pipelines</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/050-deep-learning-engineering/10-training-system-project.html">Training-system project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 08</span><strong>Applied deep learning</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="deep-learning/051-applied-deep-learning/01-computer-vision-workflow.html">Computer-vision workflow</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="deep-learning/051-applied-deep-learning/10-deep-learning-capstone.html">Deep-learning capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 09</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Deep Learning outcome. Use <a href="deep-learning/051-applied-deep-learning/10-deep-learning-capstone.html">Deep-learning capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Full Stack AI → Deep Learning</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="044" href="deep-learning/044-neural-network-foundations/01-neurons-and-layers.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 044</span><strong>Neural-network foundations</strong><small>Enter with Neurons and layers. Demonstrate mastery through Neural-network project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="045" href="deep-learning/045-deep-learning-optimization/01-gradient-descent-review.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 045</span><strong>Deep-learning optimization</strong><small>Enter with Gradient-descent review. Demonstrate mastery through Optimization experiment.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="046" href="deep-learning/046-convolutional-neural-networks/01-image-tensors.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 046</span><strong>Convolutional neural networks</strong><small>Enter with Image tensors. Demonstrate mastery through Image-classification project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="047" href="deep-learning/047-sequence-models/01-sequential-data.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 047</span><strong>Sequence models</strong><small>Enter with Sequential data. Demonstrate mastery through Sequence-model project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="048" href="deep-learning/048-attention-and-transformers/01-attention-intuition.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 048</span><strong>Attention and transformers</strong><small>Enter with Attention intuition. Demonstrate mastery through Transformer project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="049" href="deep-learning/049-autoencoders-and-generative-deep-learning/01-autoencoders.html">
# <span class="path-index">06</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 049</span><strong>Autoencoders and generative deep learning</strong><small>Enter with Autoencoders. Demonstrate mastery through Generative project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="050" href="deep-learning/050-deep-learning-engineering/01-dataset-pipelines.html">
# <span class="path-index">07</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 050</span><strong>Deep-learning engineering</strong><small>Enter with Dataset pipelines. Demonstrate mastery through Training-system project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="051" href="deep-learning/051-applied-deep-learning/01-computer-vision-workflow.html">
# <span class="path-index">08</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 051</span><strong>Applied deep learning</strong><small>Enter with Computer-vision workflow. Demonstrate mastery through Deep-learning capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Deep Learning workflow</strong><p>Combine evidence from every stage and finish with Deep-learning capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="full-stack-ai-deep-learning-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="full-stack-ai-deep-learning-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Deep Learning syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="full-stack-ai-deep-learning-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 044</span><strong>Neural-network foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/01-neurons-and-layers.html"><span>044.01</span><strong>Neurons and layers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/02-tensors.html"><span>044.02</span><strong>Tensors</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/03-forward-propagation.html"><span>044.03</span><strong>Forward propagation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/04-activation-functions.html"><span>044.04</span><strong>Activation functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/05-loss-functions.html"><span>044.05</span><strong>Loss functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/06-backpropagation.html"><span>044.06</span><strong>Backpropagation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/07-computational-graphs.html"><span>044.07</span><strong>Computational graphs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/08-weight-initialization.html"><span>044.08</span><strong>Weight initialization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/09-first-network.html"><span>044.09</span><strong>First network</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/044-neural-network-foundations/10-neural-network-project.html"><span>044.10</span><strong>Neural-network project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 045</span><strong>Deep-learning optimization</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/01-gradient-descent-review.html"><span>045.01</span><strong>Gradient-descent review</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/02-stochastic-gradient-descent.html"><span>045.02</span><strong>Stochastic gradient descent</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/03-momentum.html"><span>045.03</span><strong>Momentum</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/04-rmsprop.html"><span>045.04</span><strong>RMSProp</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/05-adam.html"><span>045.05</span><strong>Adam</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/06-learning-rate-schedules.html"><span>045.06</span><strong>Learning-rate schedules</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/07-batch-normalization.html"><span>045.07</span><strong>Batch normalization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/08-dropout.html"><span>045.08</span><strong>Dropout</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/09-regularization.html"><span>045.09</span><strong>Regularization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/045-deep-learning-optimization/10-optimization-experiment.html"><span>045.10</span><strong>Optimization experiment</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 046</span><strong>Convolutional neural networks</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/01-image-tensors.html"><span>046.01</span><strong>Image tensors</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/02-convolution-operation.html"><span>046.02</span><strong>Convolution operation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/03-filters-and-feature-maps.html"><span>046.03</span><strong>Filters and feature maps</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/04-padding-and-stride.html"><span>046.04</span><strong>Padding and stride</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/05-pooling.html"><span>046.05</span><strong>Pooling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/06-cnn-architectures.html"><span>046.06</span><strong>CNN architectures</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/07-image-augmentation.html"><span>046.07</span><strong>Image augmentation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/08-transfer-learning.html"><span>046.08</span><strong>Transfer learning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/09-cnn-evaluation.html"><span>046.09</span><strong>CNN evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/046-convolutional-neural-networks/10-image-classification-project.html"><span>046.10</span><strong>Image-classification project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 047</span><strong>Sequence models</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/01-sequential-data.html"><span>047.01</span><strong>Sequential data</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/02-recurrent-neural-networks.html"><span>047.02</span><strong>Recurrent neural networks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/03-vanishing-gradients.html"><span>047.03</span><strong>Vanishing gradients</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/04-lstm.html"><span>047.04</span><strong>LSTM</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/05-gru.html"><span>047.05</span><strong>GRU</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/06-bidirectional-models.html"><span>047.06</span><strong>Bidirectional models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/07-sequence-classification.html"><span>047.07</span><strong>Sequence classification</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/08-time-series-forecasting.html"><span>047.08</span><strong>Time-series forecasting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/09-sequence-evaluation.html"><span>047.09</span><strong>Sequence evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/047-sequence-models/10-sequence-model-project.html"><span>047.10</span><strong>Sequence-model project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 048</span><strong>Attention and transformers</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/01-attention-intuition.html"><span>048.01</span><strong>Attention intuition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/02-query-key-and-value.html"><span>048.02</span><strong>Query key and value</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/03-scaled-dot-product-attention.html"><span>048.03</span><strong>Scaled dot-product attention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/04-multi-head-attention.html"><span>048.04</span><strong>Multi-head attention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/05-positional-encoding.html"><span>048.05</span><strong>Positional encoding</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/06-transformer-encoders.html"><span>048.06</span><strong>Transformer encoders</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/07-transformer-decoders.html"><span>048.07</span><strong>Transformer decoders</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/08-masked-attention.html"><span>048.08</span><strong>Masked attention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/09-transformer-implementation.html"><span>048.09</span><strong>Transformer implementation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/048-attention-and-transformers/10-transformer-project.html"><span>048.10</span><strong>Transformer project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 049</span><strong>Autoencoders and generative deep learning</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/01-autoencoders.html"><span>049.01</span><strong>Autoencoders</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/02-latent-representations.html"><span>049.02</span><strong>Latent representations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/03-denoising-autoencoders.html"><span>049.03</span><strong>Denoising autoencoders</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/04-variational-autoencoders.html"><span>049.04</span><strong>Variational autoencoders</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/05-generative-adversarial-networks.html"><span>049.05</span><strong>Generative adversarial networks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/06-gan-training.html"><span>049.06</span><strong>GAN training</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/07-diffusion-model-intuition.html"><span>049.07</span><strong>Diffusion-model intuition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/08-conditional-generation.html"><span>049.08</span><strong>Conditional generation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/09-generative-evaluation.html"><span>049.09</span><strong>Generative evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/049-autoencoders-and-generative-deep-learning/10-generative-project.html"><span>049.10</span><strong>Generative project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 050</span><strong>Deep-learning engineering</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/01-dataset-pipelines.html"><span>050.01</span><strong>Dataset pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/02-gpu-fundamentals.html"><span>050.02</span><strong>GPU fundamentals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/03-training-loops.html"><span>050.03</span><strong>Training loops</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/04-checkpointing.html"><span>050.04</span><strong>Checkpointing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/05-mixed-precision.html"><span>050.05</span><strong>Mixed precision</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/06-distributed-training-concepts.html"><span>050.06</span><strong>Distributed-training concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/07-hyperparameter-tuning.html"><span>050.07</span><strong>Hyperparameter tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/08-experiment-tracking.html"><span>050.08</span><strong>Experiment tracking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/09-model-serving.html"><span>050.09</span><strong>Model serving</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/050-deep-learning-engineering/10-training-system-project.html"><span>050.10</span><strong>Training-system project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 051</span><strong>Applied deep learning</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/01-computer-vision-workflow.html"><span>051.01</span><strong>Computer-vision workflow</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/02-nlp-workflow.html"><span>051.02</span><strong>NLP workflow</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/03-audio-workflow.html"><span>051.03</span><strong>Audio workflow</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/04-multimodal-learning.html"><span>051.04</span><strong>Multimodal learning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/05-recommendation-models.html"><span>051.05</span><strong>Recommendation models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/06-anomaly-detection.html"><span>051.06</span><strong>Anomaly detection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/07-explainability.html"><span>051.07</span><strong>Explainability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/08-robustness.html"><span>051.08</span><strong>Robustness</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/09-responsible-deep-learning.html"><span>051.09</span><strong>Responsible deep learning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="deep-learning/051-applied-deep-learning/10-deep-learning-capstone.html"><span>051.10</span><strong>Deep-learning capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="full-stack-ai-deep-learning-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("full-stack-ai-deep-learning-catalog");
#   const search = document.getElementById("full-stack-ai-deep-learning-catalog-search");
#   const empty = document.getElementById("full-stack-ai-deep-learning-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Deep Learning** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
