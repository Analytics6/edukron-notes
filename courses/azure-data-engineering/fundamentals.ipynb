# %% [raw]
# ---
# title: "Data Engineering Fundamentals"
# description: "Complete notebook syllabus for Data Engineering Fundamentals in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>fundamentals.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>Data Engineering Fundamentals</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="fundamentals/091-modern-data-architecture/01-data-platform-components.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Data Engineering Fundamentals with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>6 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Modern data architecture</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="fundamentals/091-modern-data-architecture/01-data-platform-components.html">Data-platform components</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="fundamentals/091-modern-data-architecture/10-architecture-case-study.html">Architecture case study</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Batch data engineering</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="fundamentals/092-batch-data-engineering/01-batch-processing-concepts.html">Batch-processing concepts</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="fundamentals/092-batch-data-engineering/10-batch-platform-project.html">Batch-platform project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Streaming data engineering</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="fundamentals/093-streaming-data-engineering/01-event-stream-concepts.html">Event-stream concepts</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="fundamentals/093-streaming-data-engineering/10-streaming-architecture-project.html">Streaming architecture project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Data modeling and governance</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="fundamentals/094-data-modeling-and-governance/01-conceptual-models.html">Conceptual models</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="fundamentals/094-data-modeling-and-governance/10-governed-model-project.html">Governed-model project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Reliable secure and economical platforms</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="fundamentals/095-reliable-secure-and-economical-platforms/01-reliability-objectives.html">Reliability objectives</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="fundamentals/095-reliable-secure-and-economical-platforms/10-platform-design-capstone.html">Platform-design capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 06</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Data Engineering Fundamentals outcome. Use <a href="fundamentals/095-reliable-secure-and-economical-platforms/10-platform-design-capstone.html">Platform-design capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure Data Engineering → Data Engineering Fundamentals</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="091" href="fundamentals/091-modern-data-architecture/01-data-platform-components.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 091</span><strong>Modern data architecture</strong><small>Enter with Data-platform components. Demonstrate mastery through Architecture case study.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="092" href="fundamentals/092-batch-data-engineering/01-batch-processing-concepts.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 092</span><strong>Batch data engineering</strong><small>Enter with Batch-processing concepts. Demonstrate mastery through Batch-platform project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="093" href="fundamentals/093-streaming-data-engineering/01-event-stream-concepts.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 093</span><strong>Streaming data engineering</strong><small>Enter with Event-stream concepts. Demonstrate mastery through Streaming architecture project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="094" href="fundamentals/094-data-modeling-and-governance/01-conceptual-models.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 094</span><strong>Data modeling and governance</strong><small>Enter with Conceptual models. Demonstrate mastery through Governed-model project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="095" href="fundamentals/095-reliable-secure-and-economical-platforms/01-reliability-objectives.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 095</span><strong>Reliable secure and economical platforms</strong><small>Enter with Reliability objectives. Demonstrate mastery through Platform-design capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Data Engineering Fundamentals workflow</strong><p>Combine evidence from every stage and finish with Platform-design capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-data-engineering-fundamentals-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-data-engineering-fundamentals-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Data Engineering Fundamentals syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-data-engineering-fundamentals-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 091</span><strong>Modern data architecture</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/01-data-platform-components.html"><span>091.01</span><strong>Data-platform components</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/02-data-warehouse.html"><span>091.02</span><strong>Data warehouse</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/03-data-lake.html"><span>091.03</span><strong>Data lake</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/04-lakehouse.html"><span>091.04</span><strong>Lakehouse</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/05-data-mesh.html"><span>091.05</span><strong>Data mesh</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/06-lambda-architecture.html"><span>091.06</span><strong>Lambda architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/07-kappa-architecture.html"><span>091.07</span><strong>Kappa architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/08-medallion-architecture.html"><span>091.08</span><strong>Medallion architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/09-technology-selection.html"><span>091.09</span><strong>Technology selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/091-modern-data-architecture/10-architecture-case-study.html"><span>091.10</span><strong>Architecture case study</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 092</span><strong>Batch data engineering</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/01-batch-processing-concepts.html"><span>092.01</span><strong>Batch-processing concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/02-etl-versus-elt.html"><span>092.02</span><strong>ETL versus ELT</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/03-scheduling.html"><span>092.03</span><strong>Scheduling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/04-dependencies.html"><span>092.04</span><strong>Dependencies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/05-incremental-processing.html"><span>092.05</span><strong>Incremental processing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/06-backfills.html"><span>092.06</span><strong>Backfills</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/07-late-data.html"><span>092.07</span><strong>Late data</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/08-idempotency.html"><span>092.08</span><strong>Idempotency</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/09-batch-monitoring.html"><span>092.09</span><strong>Batch monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/092-batch-data-engineering/10-batch-platform-project.html"><span>092.10</span><strong>Batch-platform project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 093</span><strong>Streaming data engineering</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/01-event-stream-concepts.html"><span>093.01</span><strong>Event-stream concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/02-producers-and-consumers.html"><span>093.02</span><strong>Producers and consumers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/03-partitions.html"><span>093.03</span><strong>Partitions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/04-offsets.html"><span>093.04</span><strong>Offsets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/05-delivery-guarantees.html"><span>093.05</span><strong>Delivery guarantees</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/06-event-time.html"><span>093.06</span><strong>Event time</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/07-windows.html"><span>093.07</span><strong>Windows</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/08-watermarks.html"><span>093.08</span><strong>Watermarks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/09-streaming-reliability.html"><span>093.09</span><strong>Streaming reliability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/093-streaming-data-engineering/10-streaming-architecture-project.html"><span>093.10</span><strong>Streaming architecture project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 094</span><strong>Data modeling and governance</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/01-conceptual-models.html"><span>094.01</span><strong>Conceptual models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/02-logical-models.html"><span>094.02</span><strong>Logical models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/03-physical-models.html"><span>094.03</span><strong>Physical models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/04-dimensional-modeling.html"><span>094.04</span><strong>Dimensional modeling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/05-data-vault-concepts.html"><span>094.05</span><strong>Data vault concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/06-metadata-management.html"><span>094.06</span><strong>Metadata management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/07-data-catalogues.html"><span>094.07</span><strong>Data catalogues</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/08-lineage.html"><span>094.08</span><strong>Lineage</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/09-data-ownership.html"><span>094.09</span><strong>Data ownership</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/094-data-modeling-and-governance/10-governed-model-project.html"><span>094.10</span><strong>Governed-model project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 095</span><strong>Reliable secure and economical platforms</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/01-reliability-objectives.html"><span>095.01</span><strong>Reliability objectives</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/02-data-observability.html"><span>095.02</span><strong>Data observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/03-security-layers.html"><span>095.03</span><strong>Security layers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/04-identity-and-access.html"><span>095.04</span><strong>Identity and access</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/05-encryption.html"><span>095.05</span><strong>Encryption</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/06-privacy.html"><span>095.06</span><strong>Privacy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/07-disaster-recovery.html"><span>095.07</span><strong>Disaster recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/08-cost-allocation.html"><span>095.08</span><strong>Cost allocation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/09-finops-optimization.html"><span>095.09</span><strong>FinOps optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="fundamentals/095-reliable-secure-and-economical-platforms/10-platform-design-capstone.html"><span>095.10</span><strong>Platform-design capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-data-engineering-fundamentals-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-data-engineering-fundamentals-catalog");
#   const search = document.getElementById("azure-data-engineering-data-engineering-fundamentals-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-data-engineering-fundamentals-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Data Engineering Fundamentals** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
