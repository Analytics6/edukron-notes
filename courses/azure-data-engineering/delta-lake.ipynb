# %% [raw]
# ---
# title: "Delta Lake"
# description: "Complete notebook syllabus for Delta Lake in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>delta-lake.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>Delta Lake</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="delta-lake/127-delta-table-foundations/01-delta-architecture.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Delta Lake with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>5 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>3 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Delta-table foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="delta-lake/127-delta-table-foundations/01-delta-architecture.html">Delta architecture</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="delta-lake/127-delta-table-foundations/10-delta-foundations-project.html">Delta foundations project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Schema and change processing</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="delta-lake/128-schema-and-change-processing/01-schema-enforcement.html">Schema enforcement</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="delta-lake/128-schema-and-change-processing/10-change-processing-project.html">Change-processing project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Delta performance and reliability</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="delta-lake/129-delta-performance-and-reliability/01-partitioning.html">Partitioning</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="delta-lake/129-delta-performance-and-reliability/10-performance-project.html">Performance project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Streaming and governed Delta Lake</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="delta-lake/130-streaming-and-governed-delta-lake/01-streaming-reads.html">Streaming reads</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="delta-lake/130-streaming-and-governed-delta-lake/10-delta-lake-capstone.html">Delta Lake capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 05</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Delta Lake outcome. Use <a href="delta-lake/130-streaming-and-governed-delta-lake/10-delta-lake-capstone.html">Delta Lake capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure Data Engineering → Delta Lake</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="127" href="delta-lake/127-delta-table-foundations/01-delta-architecture.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 127</span><strong>Delta-table foundations</strong><small>Enter with Delta architecture. Demonstrate mastery through Delta foundations project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="128" href="delta-lake/128-schema-and-change-processing/01-schema-enforcement.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 128</span><strong>Schema and change processing</strong><small>Enter with Schema enforcement. Demonstrate mastery through Change-processing project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="129" href="delta-lake/129-delta-performance-and-reliability/01-partitioning.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 129</span><strong>Delta performance and reliability</strong><small>Enter with Partitioning. Demonstrate mastery through Performance project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="130" href="delta-lake/130-streaming-and-governed-delta-lake/01-streaming-reads.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 130</span><strong>Streaming and governed Delta Lake</strong><small>Enter with Streaming reads. Demonstrate mastery through Delta Lake capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Delta Lake workflow</strong><p>Combine evidence from every stage and finish with Delta Lake capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-delta-lake-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-delta-lake-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Delta Lake syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-delta-lake-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 127</span><strong>Delta-table foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/01-delta-architecture.html"><span>127.01</span><strong>Delta architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/02-transaction-log.html"><span>127.02</span><strong>Transaction log</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/03-creating-tables.html"><span>127.03</span><strong>Creating tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/04-reading-and-writing.html"><span>127.04</span><strong>Reading and writing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/05-acid-properties.html"><span>127.05</span><strong>ACID properties</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/06-table-history.html"><span>127.06</span><strong>Table history</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/07-time-travel.html"><span>127.07</span><strong>Time travel</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/08-constraints.html"><span>127.08</span><strong>Constraints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/09-table-inspection.html"><span>127.09</span><strong>Table inspection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/127-delta-table-foundations/10-delta-foundations-project.html"><span>127.10</span><strong>Delta foundations project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 128</span><strong>Schema and change processing</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/01-schema-enforcement.html"><span>128.01</span><strong>Schema enforcement</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/02-schema-evolution.html"><span>128.02</span><strong>Schema evolution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/03-merge.html"><span>128.03</span><strong>MERGE</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/04-upserts.html"><span>128.04</span><strong>Upserts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/05-deletes.html"><span>128.05</span><strong>Deletes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/06-change-data-feed.html"><span>128.06</span><strong>Change Data Feed</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/07-slowly-changing-dimensions.html"><span>128.07</span><strong>Slowly changing dimensions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/08-deduplication.html"><span>128.08</span><strong>Deduplication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/09-incremental-processing.html"><span>128.09</span><strong>Incremental processing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/128-schema-and-change-processing/10-change-processing-project.html"><span>128.10</span><strong>Change-processing project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 129</span><strong>Delta performance and reliability</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/01-partitioning.html"><span>129.01</span><strong>Partitioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/02-compaction.html"><span>129.02</span><strong>Compaction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/03-optimize-operations.html"><span>129.03</span><strong>Optimize operations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/04-data-skipping.html"><span>129.04</span><strong>Data skipping</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/05-clustering-concepts.html"><span>129.05</span><strong>Clustering concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/06-vacuum.html"><span>129.06</span><strong>Vacuum</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/07-retention.html"><span>129.07</span><strong>Retention</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/08-concurrent-writes.html"><span>129.08</span><strong>Concurrent writes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/09-recovery.html"><span>129.09</span><strong>Recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/129-delta-performance-and-reliability/10-performance-project.html"><span>129.10</span><strong>Performance project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 130</span><strong>Streaming and governed Delta Lake</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/01-streaming-reads.html"><span>130.01</span><strong>Streaming reads</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/02-streaming-writes.html"><span>130.02</span><strong>Streaming writes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/03-checkpoints.html"><span>130.03</span><strong>Checkpoints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/04-exactly-once-concepts.html"><span>130.04</span><strong>Exactly-once concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/05-medallion-pipelines.html"><span>130.05</span><strong>Medallion pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/06-table-permissions.html"><span>130.06</span><strong>Table permissions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/07-lineage.html"><span>130.07</span><strong>Lineage</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/08-quality-expectations.html"><span>130.08</span><strong>Quality expectations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/09-operational-monitoring.html"><span>130.09</span><strong>Operational monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="delta-lake/130-streaming-and-governed-delta-lake/10-delta-lake-capstone.html"><span>130.10</span><strong>Delta Lake capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-delta-lake-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-delta-lake-catalog");
#   const search = document.getElementById("azure-data-engineering-delta-lake-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-delta-lake-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Delta Lake** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
