# %% [raw]
# ---
# title: "Azure Databricks"
# description: "Complete notebook syllabus for Azure Databricks in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>azure-databricks.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>Azure Databricks</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="azure-databricks/106-databricks-workspace-foundations/01-workspace-architecture.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Azure Databricks with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>7 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Databricks workspace foundations</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-databricks/106-databricks-workspace-foundations/01-workspace-architecture.html">Workspace architecture</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-databricks/106-databricks-workspace-foundations/10-databricks-foundations-project.html">Databricks foundations project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Spark data engineering in Databricks</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-databricks/107-spark-data-engineering-in-databricks/01-sparksession.html">SparkSession</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-databricks/107-spark-data-engineering-in-databricks/10-spark-pipeline-project.html">Spark pipeline project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Delta Lake and lakehouse architecture</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-databricks/108-delta-lake-and-lakehouse-architecture/01-delta-tables.html">Delta tables</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-databricks/108-delta-lake-and-lakehouse-architecture/10-lakehouse-project.html">Lakehouse project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Databricks workflows and managed pipelines</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-databricks/109-databricks-workflows-and-managed-pipelines/01-jobs.html">Jobs</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-databricks/109-databricks-workflows-and-managed-pipelines/10-production-workflow-project.html">Production workflow project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Unity Catalog and security</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-databricks/110-unity-catalog-and-security/01-unity-catalog-architecture.html">Unity Catalog architecture</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-databricks/110-unity-catalog-and-security/10-governed-lakehouse-project.html">Governed-lakehouse project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 06</span><strong>Databricks performance and deployment</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-databricks/111-databricks-performance-and-deployment/01-query-plans.html">Query plans</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-databricks/111-databricks-performance-and-deployment/10-databricks-capstone.html">Databricks capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 07</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Azure Databricks outcome. Use <a href="azure-databricks/111-databricks-performance-and-deployment/10-databricks-capstone.html">Databricks capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure Data Engineering → Azure Databricks</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="106" href="azure-databricks/106-databricks-workspace-foundations/01-workspace-architecture.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 106</span><strong>Databricks workspace foundations</strong><small>Enter with Workspace architecture. Demonstrate mastery through Databricks foundations project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="107" href="azure-databricks/107-spark-data-engineering-in-databricks/01-sparksession.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 107</span><strong>Spark data engineering in Databricks</strong><small>Enter with SparkSession. Demonstrate mastery through Spark pipeline project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="108" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/01-delta-tables.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 108</span><strong>Delta Lake and lakehouse architecture</strong><small>Enter with Delta tables. Demonstrate mastery through Lakehouse project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="109" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/01-jobs.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 109</span><strong>Databricks workflows and managed pipelines</strong><small>Enter with Jobs. Demonstrate mastery through Production workflow project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="110" href="azure-databricks/110-unity-catalog-and-security/01-unity-catalog-architecture.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 110</span><strong>Unity Catalog and security</strong><small>Enter with Unity Catalog architecture. Demonstrate mastery through Governed-lakehouse project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="111" href="azure-databricks/111-databricks-performance-and-deployment/01-query-plans.html">
# <span class="path-index">06</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 111</span><strong>Databricks performance and deployment</strong><small>Enter with Query plans. Demonstrate mastery through Databricks capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Azure Databricks workflow</strong><p>Combine evidence from every stage and finish with Databricks capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-azure-databricks-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-azure-databricks-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Azure Databricks syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-azure-databricks-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 106</span><strong>Databricks workspace foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/01-workspace-architecture.html"><span>106.01</span><strong>Workspace architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/02-notebooks.html"><span>106.02</span><strong>Notebooks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/03-compute-types.html"><span>106.03</span><strong>Compute types</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/04-cluster-configuration.html"><span>106.04</span><strong>Cluster configuration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/05-libraries.html"><span>106.05</span><strong>Libraries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/06-repos-and-git.html"><span>106.06</span><strong>Repos and Git</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/07-widgets.html"><span>106.07</span><strong>Widgets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/08-secrets.html"><span>106.08</span><strong>Secrets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/09-workspace-organization.html"><span>106.09</span><strong>Workspace organization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/106-databricks-workspace-foundations/10-databricks-foundations-project.html"><span>106.10</span><strong>Databricks foundations project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 107</span><strong>Spark data engineering in Databricks</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/01-sparksession.html"><span>107.01</span><strong>SparkSession</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/02-dataframe-ingestion.html"><span>107.02</span><strong>DataFrame ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/03-transformations.html"><span>107.03</span><strong>Transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/04-aggregations.html"><span>107.04</span><strong>Aggregations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/05-joins.html"><span>107.05</span><strong>Joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/06-window-functions.html"><span>107.06</span><strong>Window functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/07-spark-sql.html"><span>107.07</span><strong>Spark SQL</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/08-user-defined-functions.html"><span>107.08</span><strong>User-defined functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/09-data-writing.html"><span>107.09</span><strong>Data writing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/107-spark-data-engineering-in-databricks/10-spark-pipeline-project.html"><span>107.10</span><strong>Spark pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 108</span><strong>Delta Lake and lakehouse architecture</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/01-delta-tables.html"><span>108.01</span><strong>Delta tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/02-acid-transactions.html"><span>108.02</span><strong>ACID transactions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/03-schema-enforcement.html"><span>108.03</span><strong>Schema enforcement</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/04-schema-evolution.html"><span>108.04</span><strong>Schema evolution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/05-merge.html"><span>108.05</span><strong>MERGE</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/06-time-travel.html"><span>108.06</span><strong>Time travel</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/07-change-data-feed.html"><span>108.07</span><strong>Change Data Feed</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/08-optimization.html"><span>108.08</span><strong>Optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/09-medallion-architecture.html"><span>108.09</span><strong>Medallion architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/108-delta-lake-and-lakehouse-architecture/10-lakehouse-project.html"><span>108.10</span><strong>Lakehouse project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 109</span><strong>Databricks workflows and managed pipelines</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/01-jobs.html"><span>109.01</span><strong>Jobs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/02-tasks.html"><span>109.02</span><strong>Tasks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/03-dependencies.html"><span>109.03</span><strong>Dependencies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/04-parameters.html"><span>109.04</span><strong>Parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/05-scheduling.html"><span>109.05</span><strong>Scheduling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/06-retries.html"><span>109.06</span><strong>Retries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/07-managed-pipeline-concepts.html"><span>109.07</span><strong>Managed pipeline concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/08-data-quality-expectations.html"><span>109.08</span><strong>Data-quality expectations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/09-workflow-monitoring.html"><span>109.09</span><strong>Workflow monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/109-databricks-workflows-and-managed-pipelines/10-production-workflow-project.html"><span>109.10</span><strong>Production workflow project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 110</span><strong>Unity Catalog and security</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/01-unity-catalog-architecture.html"><span>110.01</span><strong>Unity Catalog architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/02-metastores.html"><span>110.02</span><strong>Metastores</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/03-catalogues-and-schemas.html"><span>110.03</span><strong>Catalogues and schemas</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/04-managed-and-external-tables.html"><span>110.04</span><strong>Managed and external tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/05-storage-credentials.html"><span>110.05</span><strong>Storage credentials</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/06-external-locations.html"><span>110.06</span><strong>External locations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/07-privileges.html"><span>110.07</span><strong>Privileges</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/08-row-and-column-controls.html"><span>110.08</span><strong>Row and column controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/09-lineage.html"><span>110.09</span><strong>Lineage</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/110-unity-catalog-and-security/10-governed-lakehouse-project.html"><span>110.10</span><strong>Governed-lakehouse project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 111</span><strong>Databricks performance and deployment</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/01-query-plans.html"><span>111.01</span><strong>Query plans</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/02-adaptive-execution.html"><span>111.02</span><strong>Adaptive execution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/03-partition-tuning.html"><span>111.03</span><strong>Partition tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/04-file-compaction.html"><span>111.04</span><strong>File compaction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/05-data-skipping.html"><span>111.05</span><strong>Data skipping</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/06-photon-concepts.html"><span>111.06</span><strong>Photon concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/07-cost-controls.html"><span>111.07</span><strong>Cost controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/08-testing.html"><span>111.08</span><strong>Testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/09-ci-cd.html"><span>111.09</span><strong>CI/CD</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-databricks/111-databricks-performance-and-deployment/10-databricks-capstone.html"><span>111.10</span><strong>Databricks capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-azure-databricks-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-azure-databricks-catalog");
#   const search = document.getElementById("azure-data-engineering-azure-databricks-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-azure-databricks-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Azure Databricks** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
