# %% [raw]
# ---
# title: "SQL"
# description: "Complete notebook syllabus for SQL in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>sql.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>SQL</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="sql/086-staging-and-ingestion-sql/01-staging-table-design.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing SQL with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>6 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Staging and ingestion SQL</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="sql/086-staging-and-ingestion-sql/01-staging-table-design.html">Staging-table design</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="sql/086-staging-and-ingestion-sql/10-staging-project.html">Staging project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Transformation SQL</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="sql/087-transformation-sql/01-cleaning-transformations.html">Cleaning transformations</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="sql/087-transformation-sql/10-transformation-project.html">Transformation project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Warehouse SQL</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="sql/088-warehouse-sql/01-dimensional-queries.html">Dimensional queries</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="sql/088-warehouse-sql/10-warehouse-project.html">Warehouse project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>SQL performance engineering</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="sql/089-sql-performance-engineering/01-execution-plans.html">Execution plans</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="sql/089-sql-performance-engineering/10-tuning-project.html">Tuning project</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>SQL quality and operations</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="sql/090-sql-quality-and-operations/01-schema-tests.html">Schema tests</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="sql/090-sql-quality-and-operations/10-data-quality-capstone.html">Data-quality capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 06</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable SQL outcome. Use <a href="sql/090-sql-quality-and-operations/10-data-quality-capstone.html">Data-quality capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Azure Data Engineering → SQL</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="086" href="sql/086-staging-and-ingestion-sql/01-staging-table-design.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 086</span><strong>Staging and ingestion SQL</strong><small>Enter with Staging-table design. Demonstrate mastery through Staging project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="087" href="sql/087-transformation-sql/01-cleaning-transformations.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 087</span><strong>Transformation SQL</strong><small>Enter with Cleaning transformations. Demonstrate mastery through Transformation project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="088" href="sql/088-warehouse-sql/01-dimensional-queries.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 088</span><strong>Warehouse SQL</strong><small>Enter with Dimensional queries. Demonstrate mastery through Warehouse project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="089" href="sql/089-sql-performance-engineering/01-execution-plans.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 089</span><strong>SQL performance engineering</strong><small>Enter with Execution plans. Demonstrate mastery through Tuning project.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="090" href="sql/090-sql-quality-and-operations/01-schema-tests.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 090</span><strong>SQL quality and operations</strong><small>Enter with Schema tests. Demonstrate mastery through Data-quality capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete SQL workflow</strong><p>Combine evidence from every stage and finish with Data-quality capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-sql-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-sql-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the SQL syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-sql-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 086</span><strong>Staging and ingestion SQL</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/01-staging-table-design.html"><span>086.01</span><strong>Staging-table design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/02-bulk-loading.html"><span>086.02</span><strong>Bulk loading</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/03-data-type-validation.html"><span>086.03</span><strong>Data-type validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/04-reject-tables.html"><span>086.04</span><strong>Reject tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/05-deduplication.html"><span>086.05</span><strong>Deduplication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/06-watermarks.html"><span>086.06</span><strong>Watermarks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/07-incremental-loads.html"><span>086.07</span><strong>Incremental loads</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/08-merge-operations.html"><span>086.08</span><strong>Merge operations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/09-audit-columns.html"><span>086.09</span><strong>Audit columns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/086-staging-and-ingestion-sql/10-staging-project.html"><span>086.10</span><strong>Staging project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 087</span><strong>Transformation SQL</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/087-transformation-sql/01-cleaning-transformations.html"><span>087.01</span><strong>Cleaning transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/02-standardization.html"><span>087.02</span><strong>Standardization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/03-surrogate-keys.html"><span>087.03</span><strong>Surrogate keys</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/04-slowly-changing-dimensions.html"><span>087.04</span><strong>Slowly changing dimensions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/05-fact-table-loading.html"><span>087.05</span><strong>Fact-table loading</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/06-snapshot-tables.html"><span>087.06</span><strong>Snapshot tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/07-pivoting.html"><span>087.07</span><strong>Pivoting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/08-window-transformations.html"><span>087.08</span><strong>Window transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/09-reusable-sql-models.html"><span>087.09</span><strong>Reusable SQL models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/087-transformation-sql/10-transformation-project.html"><span>087.10</span><strong>Transformation project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 088</span><strong>Warehouse SQL</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/01-dimensional-queries.html"><span>088.01</span><strong>Dimensional queries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/02-star-schema-joins.html"><span>088.02</span><strong>Star-schema joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/03-time-dimensions.html"><span>088.03</span><strong>Time dimensions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/04-semi-additive-measures.html"><span>088.04</span><strong>Semi-additive measures</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/05-period-comparisons.html"><span>088.05</span><strong>Period comparisons</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/06-cohort-queries.html"><span>088.06</span><strong>Cohort queries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/07-materialized-views.html"><span>088.07</span><strong>Materialized views</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/08-aggregate-tables.html"><span>088.08</span><strong>Aggregate tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/09-serving-layer-design.html"><span>088.09</span><strong>Serving-layer design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/088-warehouse-sql/10-warehouse-project.html"><span>088.10</span><strong>Warehouse project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 089</span><strong>SQL performance engineering</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/01-execution-plans.html"><span>089.01</span><strong>Execution plans</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/02-indexing.html"><span>089.02</span><strong>Indexing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/03-partition-pruning.html"><span>089.03</span><strong>Partition pruning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/04-statistics.html"><span>089.04</span><strong>Statistics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/05-join-strategies.html"><span>089.05</span><strong>Join strategies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/06-data-distribution.html"><span>089.06</span><strong>Data distribution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/07-query-rewrites.html"><span>089.07</span><strong>Query rewrites</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/08-workload-management.html"><span>089.08</span><strong>Workload management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/09-performance-baselines.html"><span>089.09</span><strong>Performance baselines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/089-sql-performance-engineering/10-tuning-project.html"><span>089.10</span><strong>Tuning project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 090</span><strong>SQL quality and operations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/01-schema-tests.html"><span>090.01</span><strong>Schema tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/02-null-tests.html"><span>090.02</span><strong>Null tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/03-uniqueness-tests.html"><span>090.03</span><strong>Uniqueness tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/04-referential-integrity-tests.html"><span>090.04</span><strong>Referential-integrity tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/05-reconciliation.html"><span>090.05</span><strong>Reconciliation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/06-freshness-tests.html"><span>090.06</span><strong>Freshness tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/07-transaction-control.html"><span>090.07</span><strong>Transaction control</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/08-error-recovery.html"><span>090.08</span><strong>Error recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/09-sql-deployment.html"><span>090.09</span><strong>SQL deployment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="sql/090-sql-quality-and-operations/10-data-quality-capstone.html"><span>090.10</span><strong>Data-quality capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-sql-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-sql-catalog");
#   const search = document.getElementById("azure-data-engineering-sql-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-sql-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **SQL** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
