# %% [raw]
# ---
# title: "Azure Data Factory"
# description: "Complete notebook syllabus for Azure Data Factory in Azure Data Engineering."
# author: "Edukron Notes"
# date: "2026-09-14"
# toc: true
# execute: false
# ---

# %% [markdown]
# <div class="overview-lead curriculum-summary">
# <div class="overview-icon"><i class="bi bi-journal-code" aria-hidden="true"></i></div>
# <div><span class="overview-kicker">Azure Data Engineering</span><h2>Azure Data Factory</h2><p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson contains notes, a worked pattern, executable validation, a guided lab, solution blueprint, practice, and knowledge checks.</p></div>
# </div>
#
# <div class="course-stat-grid">
# <div><strong>6</strong><span>Syllabus topics</span></div>
# <div><strong>60</strong><span>Notebook lessons</span></div>
# <div><strong>Practice</strong><span>Labs and solutions</span></div>
# </div>
#
# <p class="course-start"><a class="btn btn-primary" href="azure-data-factory/096-adf-foundations/01-adf-architecture.html">Start the first notebook <i class="bi bi-arrow-right"></i></a></p>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# ## Full syllabus
#
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 096</span><strong>ADF foundations</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/01-adf-architecture.html"><span>096.01</span><strong>ADF architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/02-factories-and-resources.html"><span>096.02</span><strong>Factories and resources</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/03-linked-services.html"><span>096.03</span><strong>Linked services</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/04-datasets.html"><span>096.04</span><strong>Datasets</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/05-pipelines.html"><span>096.05</span><strong>Pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/06-activities.html"><span>096.06</span><strong>Activities</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/07-authoring-interface.html"><span>096.07</span><strong>Authoring interface</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/08-publish-model.html"><span>096.08</span><strong>Publish model</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/09-first-pipeline.html"><span>096.09</span><strong>First pipeline</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/096-adf-foundations/10-adf-foundations-project.html"><span>096.10</span><strong>ADF foundations project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 097</span><strong>Copy Activity and Mapping Data Flows</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/01-copy-activity.html"><span>097.01</span><strong>Copy Activity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/02-source-configuration.html"><span>097.02</span><strong>Source configuration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/03-sink-configuration.html"><span>097.03</span><strong>Sink configuration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/04-schema-mapping.html"><span>097.04</span><strong>Schema mapping</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/05-fault-tolerance.html"><span>097.05</span><strong>Fault tolerance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/06-data-flow-foundations.html"><span>097.06</span><strong>Data-flow foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/07-transformations.html"><span>097.07</span><strong>Transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/08-debug-sessions.html"><span>097.08</span><strong>Debug sessions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/09-data-flow-performance.html"><span>097.09</span><strong>Data-flow performance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/097-copy-activity-and-mapping-data-flows/10-copy-and-transform-project.html"><span>097.10</span><strong>Copy-and-transform project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 098</span><strong>Parameters and metadata-driven pipelines</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/01-pipeline-parameters.html"><span>098.01</span><strong>Pipeline parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/02-dataset-parameters.html"><span>098.02</span><strong>Dataset parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/03-variables.html"><span>098.03</span><strong>Variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/04-expressions.html"><span>098.04</span><strong>Expressions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/05-system-variables.html"><span>098.05</span><strong>System variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/06-lookup-activity.html"><span>098.06</span><strong>Lookup Activity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/07-foreach-activity.html"><span>098.07</span><strong>ForEach Activity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/08-metadata-tables.html"><span>098.08</span><strong>Metadata tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/09-dynamic-paths.html"><span>098.09</span><strong>Dynamic paths</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/098-parameters-and-metadata-driven-pipelines/10-metadata-driven-project.html"><span>098.10</span><strong>Metadata-driven project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 099</span><strong>Control flow and triggers</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/01-dependency-conditions.html"><span>099.01</span><strong>Dependency conditions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/02-if-condition.html"><span>099.02</span><strong>If Condition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/03-switch-activity.html"><span>099.03</span><strong>Switch Activity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/04-until-activity.html"><span>099.04</span><strong>Until Activity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/05-execute-pipeline.html"><span>099.05</span><strong>Execute Pipeline</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/06-schedule-triggers.html"><span>099.06</span><strong>Schedule triggers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/07-tumbling-window-triggers.html"><span>099.07</span><strong>Tumbling-window triggers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/08-event-triggers.html"><span>099.08</span><strong>Event triggers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/09-trigger-recovery.html"><span>099.09</span><strong>Trigger recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/099-control-flow-and-triggers/10-orchestration-project.html"><span>099.10</span><strong>Orchestration project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 100</span><strong>Integration Runtime and security</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/01-azure-integration-runtime.html"><span>100.01</span><strong>Azure Integration Runtime</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/02-self-hosted-integration-runtime.html"><span>100.02</span><strong>Self-hosted Integration Runtime</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/03-managed-virtual-networks.html"><span>100.03</span><strong>Managed virtual networks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/04-private-endpoints.html"><span>100.04</span><strong>Private endpoints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/05-managed-identity.html"><span>100.05</span><strong>Managed identity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/06-key-vault-integration.html"><span>100.06</span><strong>Key Vault integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/07-rbac.html"><span>100.07</span><strong>RBAC</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/08-network-troubleshooting.html"><span>100.08</span><strong>Network troubleshooting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/09-secure-connectivity.html"><span>100.09</span><strong>Secure connectivity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/100-integration-runtime-and-security/10-secure-adf-project.html"><span>100.10</span><strong>Secure-ADF project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 101</span><strong>ADF monitoring and CI/CD</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/01-pipeline-monitoring.html"><span>101.01</span><strong>Pipeline monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/02-activity-diagnostics.html"><span>101.02</span><strong>Activity diagnostics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/03-alerts.html"><span>101.03</span><strong>Alerts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/04-reruns-and-recovery.html"><span>101.04</span><strong>Reruns and recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/05-git-integration.html"><span>101.05</span><strong>Git integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/06-branching-workflow.html"><span>101.06</span><strong>Branching workflow</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/07-arm-deployment.html"><span>101.07</span><strong>ARM deployment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/08-environment-parameters.html"><span>101.08</span><strong>Environment parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/09-release-validation.html"><span>101.09</span><strong>Release validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-factory/101-adf-monitoring-and-ci-cd/10-production-adf-capstone.html"><span>101.10</span><strong>Production-ADF capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>

# %% [markdown]
# ## Completion standard
#
# You have completed **Azure Data Factory** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
