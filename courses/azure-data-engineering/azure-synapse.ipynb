# %% [raw]
# ---
# title: "Azure Synapse Analytics"
# description: "Complete notebook syllabus for Azure Synapse Analytics in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>azure-synapse.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>Azure Synapse Analytics</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="azure-synapse/119-synapse-architecture/01-synapse-workspace.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-azure-synapse-analytics-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-azure-synapse-analytics-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Azure Synapse Analytics syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-azure-synapse-analytics-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 119</span><strong>Synapse architecture</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/01-synapse-workspace.html"><span>119.01</span><strong>Synapse workspace</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/02-synapse-studio.html"><span>119.02</span><strong>Synapse Studio</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/03-sql-pools.html"><span>119.03</span><strong>SQL pools</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/04-spark-pools.html"><span>119.04</span><strong>Spark pools</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/05-pipelines.html"><span>119.05</span><strong>Pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/06-storage-integration.html"><span>119.06</span><strong>Storage integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/07-linked-services.html"><span>119.07</span><strong>Linked services</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/08-security-model.html"><span>119.08</span><strong>Security model</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/09-monitoring.html"><span>119.09</span><strong>Monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/119-synapse-architecture/10-synapse-architecture-project.html"><span>119.10</span><strong>Synapse architecture project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 120</span><strong>Synapse SQL</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/01-serverless-sql.html"><span>120.01</span><strong>Serverless SQL</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/02-external-tables.html"><span>120.02</span><strong>External tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/03-openrowset.html"><span>120.03</span><strong>OPENROWSET</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/04-dedicated-sql-pools.html"><span>120.04</span><strong>Dedicated SQL pools</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/05-distribution-strategies.html"><span>120.05</span><strong>Distribution strategies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/06-columnstore-indexes.html"><span>120.06</span><strong>Columnstore indexes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/07-partitioning.html"><span>120.07</span><strong>Partitioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/08-workload-management.html"><span>120.08</span><strong>Workload management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/09-query-tuning.html"><span>120.09</span><strong>Query tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/120-synapse-sql/10-synapse-sql-project.html"><span>120.10</span><strong>Synapse SQL project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 121</span><strong>Synapse Spark and pipelines</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/01-spark-notebooks.html"><span>121.01</span><strong>Spark notebooks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/02-dataframe-processing.html"><span>121.02</span><strong>DataFrame processing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/03-delta-integration.html"><span>121.03</span><strong>Delta integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/04-lake-databases.html"><span>121.04</span><strong>Lake databases</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/05-pipeline-activities.html"><span>121.05</span><strong>Pipeline activities</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/06-parameters.html"><span>121.06</span><strong>Parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/07-triggers.html"><span>121.07</span><strong>Triggers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/08-notebook-orchestration.html"><span>121.08</span><strong>Notebook orchestration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/09-integrated-monitoring.html"><span>121.09</span><strong>Integrated monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/121-synapse-spark-and-pipelines/10-end-to-end-synapse-project.html"><span>121.10</span><strong>End-to-end Synapse project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 122</span><strong>Synapse production engineering</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/01-managed-identity.html"><span>122.01</span><strong>Managed identity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/02-private-networking.html"><span>122.02</span><strong>Private networking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/03-access-controls.html"><span>122.03</span><strong>Access controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/04-data-protection.html"><span>122.04</span><strong>Data protection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/05-source-control.html"><span>122.05</span><strong>Source control</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/06-ci-cd.html"><span>122.06</span><strong>CI/CD</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/07-performance-baselines.html"><span>122.07</span><strong>Performance baselines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/08-cost-management.html"><span>122.08</span><strong>Cost management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/09-disaster-recovery.html"><span>122.09</span><strong>Disaster recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-synapse/122-synapse-production-engineering/10-synapse-capstone.html"><span>122.10</span><strong>Synapse capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-azure-synapse-analytics-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-azure-synapse-analytics-catalog");
#   const search = document.getElementById("azure-data-engineering-azure-synapse-analytics-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-azure-synapse-analytics-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Azure Synapse Analytics** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
