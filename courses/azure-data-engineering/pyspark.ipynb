# %% [raw]
# ---
# title: "PySpark"
# description: "Complete notebook syllabus for PySpark in Azure Data Engineering."
# author: "Edukron Notes"
# date: "2026-09-14"
# toc: true
# execute: false
# ---

# %% [markdown]
# <div class="overview-lead curriculum-summary">
# <div class="overview-icon"><i class="bi bi-journal-code" aria-hidden="true"></i></div>
# <div><span class="overview-kicker">Azure Data Engineering</span><h2>PySpark</h2><p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson contains notes, a worked pattern, executable validation, a guided lab, solution blueprint, practice, and knowledge checks.</p></div>
# </div>
#
# <div class="course-stat-grid">
# <div><strong>7</strong><span>Syllabus topics</span></div>
# <div><strong>70</strong><span>Notebook lessons</span></div>
# <div><strong>Practice</strong><span>Labs and solutions</span></div>
# </div>
#
# <p class="course-start"><a class="btn btn-primary" href="pyspark/112-spark-and-pyspark-architecture/01-distributed-computing-concepts.html">Start the first notebook <i class="bi bi-arrow-right"></i></a></p>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# ## Full syllabus
#
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 112</span><strong>Spark and PySpark architecture</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/01-distributed-computing-concepts.html"><span>112.01</span><strong>Distributed-computing concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/02-driver-and-executors.html"><span>112.02</span><strong>Driver and executors</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/03-sparksession.html"><span>112.03</span><strong>SparkSession</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/04-jobs-stages-and-tasks.html"><span>112.04</span><strong>Jobs stages and tasks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/05-lazy-evaluation.html"><span>112.05</span><strong>Lazy evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/06-transformations-and-actions.html"><span>112.06</span><strong>Transformations and actions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/07-narrow-and-wide-operations.html"><span>112.07</span><strong>Narrow and wide operations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/08-dag-inspection.html"><span>112.08</span><strong>DAG inspection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/09-local-setup.html"><span>112.09</span><strong>Local setup</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/112-spark-and-pyspark-architecture/10-architecture-lab.html"><span>112.10</span><strong>Architecture lab</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 113</span><strong>DataFrame transformations</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/01-creating-dataframes.html"><span>113.01</span><strong>Creating DataFrames</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/02-selecting-columns.html"><span>113.02</span><strong>Selecting columns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/03-filtering.html"><span>113.03</span><strong>Filtering</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/04-adding-columns.html"><span>113.04</span><strong>Adding columns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/05-renaming-and-dropping.html"><span>113.05</span><strong>Renaming and dropping</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/06-conditional-expressions.html"><span>113.06</span><strong>Conditional expressions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/07-sorting.html"><span>113.07</span><strong>Sorting</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/08-deduplication.html"><span>113.08</span><strong>Deduplication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/09-sampling.html"><span>113.09</span><strong>Sampling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/113-dataframe-transformations/10-transformation-project.html"><span>113.10</span><strong>Transformation project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 114</span><strong>PySpark functions and data types</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/01-spark-sql-types.html"><span>114.01</span><strong>Spark SQL types</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/02-schema-definitions.html"><span>114.02</span><strong>Schema definitions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/03-null-handling.html"><span>114.03</span><strong>Null handling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/04-string-functions.html"><span>114.04</span><strong>String functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/05-date-functions.html"><span>114.05</span><strong>Date functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/06-array-functions.html"><span>114.06</span><strong>Array functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/07-map-functions.html"><span>114.07</span><strong>Map functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/08-struct-functions.html"><span>114.08</span><strong>Struct functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/09-type-conversion.html"><span>114.09</span><strong>Type conversion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/114-pyspark-functions-and-data-types/10-complex-data-project.html"><span>114.10</span><strong>Complex-data project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 115</span><strong>Joins aggregations and windows</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/01-groupby.html"><span>115.01</span><strong>GroupBy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/02-aggregate-functions.html"><span>115.02</span><strong>Aggregate functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/03-inner-joins.html"><span>115.03</span><strong>Inner joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/04-outer-joins.html"><span>115.04</span><strong>Outer joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/05-semi-and-anti-joins.html"><span>115.05</span><strong>Semi and anti joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/06-join-strategies.html"><span>115.06</span><strong>Join strategies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/07-window-specifications.html"><span>115.07</span><strong>Window specifications</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/08-ranking.html"><span>115.08</span><strong>Ranking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/09-running-calculations.html"><span>115.09</span><strong>Running calculations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/115-joins-aggregations-and-windows/10-analytical-pipeline-project.html"><span>115.10</span><strong>Analytical pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 116</span><strong>PySpark input output and partitioning</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/01-csv.html"><span>116.01</span><strong>CSV</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/02-json.html"><span>116.02</span><strong>JSON</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/03-parquet.html"><span>116.03</span><strong>Parquet</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/04-delta.html"><span>116.04</span><strong>Delta</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/05-jdbc.html"><span>116.05</span><strong>JDBC</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/06-read-options.html"><span>116.06</span><strong>Read options</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/07-write-modes.html"><span>116.07</span><strong>Write modes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/08-partitioned-writes.html"><span>116.08</span><strong>Partitioned writes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/09-small-file-control.html"><span>116.09</span><strong>Small-file control</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/116-pyspark-input-output-and-partitioning/10-multi-source-project.html"><span>116.10</span><strong>Multi-source project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 117</span><strong>PySpark performance and testing</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/01-explain-plans.html"><span>117.01</span><strong>Explain plans</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/02-shuffle-reduction.html"><span>117.02</span><strong>Shuffle reduction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/03-repartition-and-coalesce.html"><span>117.03</span><strong>Repartition and coalesce</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/04-broadcast-joins.html"><span>117.04</span><strong>Broadcast joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/05-caching.html"><span>117.05</span><strong>Caching</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/06-udf-alternatives.html"><span>117.06</span><strong>UDF alternatives</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/07-memory-tuning.html"><span>117.07</span><strong>Memory tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/08-unit-testing.html"><span>117.08</span><strong>Unit testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/09-dataframe-assertions.html"><span>117.09</span><strong>DataFrame assertions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/117-pyspark-performance-and-testing/10-performance-project.html"><span>117.10</span><strong>Performance project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 118</span><strong>Structured Streaming</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/01-streaming-dataframes.html"><span>118.01</span><strong>Streaming DataFrames</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/02-sources-and-sinks.html"><span>118.02</span><strong>Sources and sinks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/03-output-modes.html"><span>118.03</span><strong>Output modes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/04-checkpoints.html"><span>118.04</span><strong>Checkpoints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/05-event-time.html"><span>118.05</span><strong>Event time</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/06-watermarks.html"><span>118.06</span><strong>Watermarks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/07-window-aggregations.html"><span>118.07</span><strong>Window aggregations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/08-streaming-joins.html"><span>118.08</span><strong>Streaming joins</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/09-recovery.html"><span>118.09</span><strong>Recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="pyspark/118-structured-streaming/10-pyspark-streaming-capstone.html"><span>118.10</span><strong>PySpark streaming capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>

# %% [markdown]
# ## Completion standard
#
# You have completed **PySpark** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
