# %% [raw]
# ---
# title: "ADLS Gen2"
# description: "Complete notebook syllabus for ADLS Gen2 in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>adls-gen2.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>ADLS Gen2</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="adls-gen2/102-adls-gen2-foundations/01-storage-account-architecture.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-adls-gen2-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-adls-gen2-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the ADLS Gen2 syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-adls-gen2-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 102</span><strong>ADLS Gen2 foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/01-storage-account-architecture.html"><span>102.01</span><strong>Storage-account architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/02-hierarchical-namespace.html"><span>102.02</span><strong>Hierarchical namespace</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/03-containers-and-directories.html"><span>102.03</span><strong>Containers and directories</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/04-blob-types.html"><span>102.04</span><strong>Blob types</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/05-naming-standards.html"><span>102.05</span><strong>Naming standards</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/06-storage-tiers.html"><span>102.06</span><strong>Storage tiers</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/07-redundancy-options.html"><span>102.07</span><strong>Redundancy options</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/08-azure-cli-access.html"><span>102.08</span><strong>Azure CLI access</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/09-sdk-access.html"><span>102.09</span><strong>SDK access</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/102-adls-gen2-foundations/10-data-lake-foundations-project.html"><span>102.10</span><strong>Data-lake foundations project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 103</span><strong>ADLS security</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/01-entra-id-authentication.html"><span>103.01</span><strong>Entra ID authentication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/02-shared-keys.html"><span>103.02</span><strong>Shared keys</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/03-sas-tokens.html"><span>103.03</span><strong>SAS tokens</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/04-rbac.html"><span>103.04</span><strong>RBAC</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/05-posix-acls.html"><span>103.05</span><strong>POSIX ACLs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/06-default-acls.html"><span>103.06</span><strong>Default ACLs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/07-private-endpoints.html"><span>103.07</span><strong>Private endpoints</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/08-firewalls.html"><span>103.08</span><strong>Firewalls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/09-encryption.html"><span>103.09</span><strong>Encryption</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/103-adls-security/10-secure-lake-project.html"><span>103.10</span><strong>Secure-lake project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 104</span><strong>Lake organization and lifecycle</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/01-raw-zone-design.html"><span>104.01</span><strong>Raw-zone design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/02-curated-zone-design.html"><span>104.02</span><strong>Curated-zone design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/03-serving-zone-design.html"><span>104.03</span><strong>Serving-zone design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/04-partitioning.html"><span>104.04</span><strong>Partitioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/05-file-sizing.html"><span>104.05</span><strong>File sizing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/06-naming-conventions.html"><span>104.06</span><strong>Naming conventions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/07-lifecycle-policies.html"><span>104.07</span><strong>Lifecycle policies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/08-versioning.html"><span>104.08</span><strong>Versioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/09-soft-delete.html"><span>104.09</span><strong>Soft delete</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/104-lake-organization-and-lifecycle/10-lake-organization-project.html"><span>104.10</span><strong>Lake-organization project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 105</span><strong>ADLS integrations and operations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/01-adf-integration.html"><span>105.01</span><strong>ADF integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/02-databricks-integration.html"><span>105.02</span><strong>Databricks integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/03-synapse-integration.html"><span>105.03</span><strong>Synapse integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/04-fabric-integration.html"><span>105.04</span><strong>Fabric integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/05-event-grid.html"><span>105.05</span><strong>Event Grid</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/06-monitoring-metrics.html"><span>105.06</span><strong>Monitoring metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/07-diagnostic-logs.html"><span>105.07</span><strong>Diagnostic logs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/08-performance-tuning.html"><span>105.08</span><strong>Performance tuning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/09-disaster-recovery.html"><span>105.09</span><strong>Disaster recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="adls-gen2/105-adls-integrations-and-operations/10-adls-capstone.html"><span>105.10</span><strong>ADLS capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-adls-gen2-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-adls-gen2-catalog");
#   const search = document.getElementById("azure-data-engineering-adls-gen2-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-adls-gen2-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **ADLS Gen2** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
