# %% [raw]
# ---
# title: "Python"
# description: "Complete notebook syllabus for Python in Azure Data Engineering."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>python.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Azure Data Engineering</span>
# <h1>Python</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="python/081-python-pipeline-foundations/01-pipeline-architecture.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="azure-data-engineering-python-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="azure-data-engineering-python-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Python syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="azure-data-engineering-python-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 081</span><strong>Python pipeline foundations</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/01-pipeline-architecture.html"><span>081.01</span><strong>Pipeline architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/02-extract-transform-and-load.html"><span>081.02</span><strong>Extract transform and load</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/03-pure-transformations.html"><span>081.03</span><strong>Pure transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/04-pipeline-configuration.html"><span>081.04</span><strong>Pipeline configuration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/05-environment-variables.html"><span>081.05</span><strong>Environment variables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/06-command-line-parameters.html"><span>081.06</span><strong>Command-line parameters</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/07-checkpointing.html"><span>081.07</span><strong>Checkpointing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/08-idempotency.html"><span>081.08</span><strong>Idempotency</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/09-pipeline-metadata.html"><span>081.09</span><strong>Pipeline metadata</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/081-python-pipeline-foundations/10-batch-pipeline-project.html"><span>081.10</span><strong>Batch-pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 082</span><strong>Files and serialization</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="python/082-files-and-serialization/01-filesystem-ingestion.html"><span>082.01</span><strong>Filesystem ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/02-csv-pipelines.html"><span>082.02</span><strong>CSV pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/03-json-pipelines.html"><span>082.03</span><strong>JSON pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/04-json-lines.html"><span>082.04</span><strong>JSON Lines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/05-parquet-concepts.html"><span>082.05</span><strong>Parquet concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/06-avro-concepts.html"><span>082.06</span><strong>Avro concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/07-compression.html"><span>082.07</span><strong>Compression</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/08-schema-validation.html"><span>082.08</span><strong>Schema validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/09-file-partitioning.html"><span>082.09</span><strong>File partitioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/082-files-and-serialization/10-multi-format-project.html"><span>082.10</span><strong>Multi-format project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 083</span><strong>API data ingestion</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/01-api-source-design.html"><span>083.01</span><strong>API-source design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/02-authentication.html"><span>083.02</span><strong>Authentication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/03-pagination.html"><span>083.03</span><strong>Pagination</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/04-rate-limits.html"><span>083.04</span><strong>Rate limits</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/05-retries.html"><span>083.05</span><strong>Retries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/06-incremental-extraction.html"><span>083.06</span><strong>Incremental extraction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/07-watermarks.html"><span>083.07</span><strong>Watermarks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/08-response-validation.html"><span>083.08</span><strong>Response validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/09-raw-data-preservation.html"><span>083.09</span><strong>Raw-data preservation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/083-api-data-ingestion/10-api-ingestion-project.html"><span>083.10</span><strong>API-ingestion project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 084</span><strong>Reliable data-engineering Python</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/01-exception-strategy.html"><span>084.01</span><strong>Exception strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/02-structured-logging.html"><span>084.02</span><strong>Structured logging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/03-metrics.html"><span>084.03</span><strong>Metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/04-unit-testing.html"><span>084.04</span><strong>Unit testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/05-integration-testing.html"><span>084.05</span><strong>Integration testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/06-test-fixtures.html"><span>084.06</span><strong>Test fixtures</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/07-data-quality-tests.html"><span>084.07</span><strong>Data-quality tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/08-secrets-management.html"><span>084.08</span><strong>Secrets management</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/09-packaging.html"><span>084.09</span><strong>Packaging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/084-reliable-data-engineering-python/10-tested-pipeline-project.html"><span>084.10</span><strong>Tested-pipeline project</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 085</span><strong>Python performance and orchestration</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/01-profiling.html"><span>085.01</span><strong>Profiling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/02-memory-efficient-iteration.html"><span>085.02</span><strong>Memory-efficient iteration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/03-chunk-processing.html"><span>085.03</span><strong>Chunk processing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/04-threaded-i-o.html"><span>085.04</span><strong>Threaded I/O</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/05-process-parallelism.html"><span>085.05</span><strong>Process parallelism</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/06-async-ingestion.html"><span>085.06</span><strong>Async ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/07-scheduling.html"><span>085.07</span><strong>Scheduling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/08-backfills.html"><span>085.08</span><strong>Backfills</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/09-recovery-workflows.html"><span>085.09</span><strong>Recovery workflows</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="python/085-python-performance-and-orchestration/10-python-data-engineering-capstone.html"><span>085.10</span><strong>Python data-engineering capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="azure-data-engineering-python-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("azure-data-engineering-python-catalog");
#   const search = document.getElementById("azure-data-engineering-python-catalog-search");
#   const empty = document.getElementById("azure-data-engineering-python-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Python** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
