# %% [raw]
# ---
# title: "Azure DevOps"
# description: "Complete notebook syllabus for Azure DevOps in Project Flows."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>azure-devops.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Project Flows</span>
# <h1>Azure DevOps</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="azure-devops/197-devops-platform-discovery-flow/01-application-assessment.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Azure DevOps with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>5 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>3 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>DevOps platform discovery flow</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-devops/197-devops-platform-discovery-flow/01-application-assessment.html">Application assessment</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-devops/197-devops-platform-discovery-flow/10-platform-blueprint.html">Platform blueprint</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>CI/CD implementation flow</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-devops/198-ci-cd-implementation-flow/01-repository-policies.html">Repository policies</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-devops/198-ci-cd-implementation-flow/10-ci-cd-release.html">CI/CD release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Container and AKS delivery flow</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-devops/199-container-and-aks-delivery-flow/01-application-containerization.html">Application containerization</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-devops/199-container-and-aks-delivery-flow/10-aks-release.html">AKS release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Infrastructure DevSecOps and operations flow</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-devops/200-infrastructure-devsecops-and-operations-flow/01-terraform-modules.html">Terraform modules</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-devops/200-infrastructure-devsecops-and-operations-flow/10-azure-devops-capstone.html">Azure DevOps capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 05</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Azure DevOps outcome. Use <a href="azure-devops/200-infrastructure-devsecops-and-operations-flow/10-azure-devops-capstone.html">Azure DevOps capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Project Flows → Azure DevOps</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="197" href="azure-devops/197-devops-platform-discovery-flow/01-application-assessment.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 197</span><strong>DevOps platform discovery flow</strong><small>Enter with Application assessment. Demonstrate mastery through Platform blueprint.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="198" href="azure-devops/198-ci-cd-implementation-flow/01-repository-policies.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 198</span><strong>CI/CD implementation flow</strong><small>Enter with Repository policies. Demonstrate mastery through CI/CD release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="199" href="azure-devops/199-container-and-aks-delivery-flow/01-application-containerization.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 199</span><strong>Container and AKS delivery flow</strong><small>Enter with Application containerization. Demonstrate mastery through AKS release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="200" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/01-terraform-modules.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 200</span><strong>Infrastructure DevSecOps and operations flow</strong><small>Enter with Terraform modules. Demonstrate mastery through Azure DevOps capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Azure DevOps workflow</strong><p>Combine evidence from every stage and finish with Azure DevOps capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="project-flows-azure-devops-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="project-flows-azure-devops-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Azure DevOps syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="project-flows-azure-devops-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 197</span><strong>DevOps platform discovery flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/01-application-assessment.html"><span>197.01</span><strong>Application assessment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/02-team-topology.html"><span>197.02</span><strong>Team topology</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/03-repository-strategy.html"><span>197.03</span><strong>Repository strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/04-environment-model.html"><span>197.04</span><strong>Environment model</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/05-security-requirements.html"><span>197.05</span><strong>Security requirements</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/06-toolchain-selection.html"><span>197.06</span><strong>Toolchain selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/07-delivery-metrics.html"><span>197.07</span><strong>Delivery metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/08-governance.html"><span>197.08</span><strong>Governance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/09-adoption-roadmap.html"><span>197.09</span><strong>Adoption roadmap</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/197-devops-platform-discovery-flow/10-platform-blueprint.html"><span>197.10</span><strong>Platform blueprint</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 198</span><strong>CI/CD implementation flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/01-repository-policies.html"><span>198.01</span><strong>Repository policies</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/02-build-pipeline.html"><span>198.02</span><strong>Build pipeline</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/03-automated-tests.html"><span>198.03</span><strong>Automated tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/04-artifact-strategy.html"><span>198.04</span><strong>Artifact strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/05-environment-promotion.html"><span>198.05</span><strong>Environment promotion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/06-deployment-strategy.html"><span>198.06</span><strong>Deployment strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/07-approvals.html"><span>198.07</span><strong>Approvals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/08-rollback.html"><span>198.08</span><strong>Rollback</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/09-pipeline-observability.html"><span>198.09</span><strong>Pipeline observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/198-ci-cd-implementation-flow/10-ci-cd-release.html"><span>198.10</span><strong>CI/CD release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 199</span><strong>Container and AKS delivery flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/01-application-containerization.html"><span>199.01</span><strong>Application containerization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/02-image-optimization.html"><span>199.02</span><strong>Image optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/03-registry-setup.html"><span>199.03</span><strong>Registry setup</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/04-aks-foundation.html"><span>199.04</span><strong>AKS foundation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/05-workload-manifests.html"><span>199.05</span><strong>Workload manifests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/06-networking-and-ingress.html"><span>199.06</span><strong>Networking and ingress</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/07-secrets-and-identity.html"><span>199.07</span><strong>Secrets and identity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/08-scaling.html"><span>199.08</span><strong>Scaling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/09-monitoring.html"><span>199.09</span><strong>Monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/199-container-and-aks-delivery-flow/10-aks-release.html"><span>199.10</span><strong>AKS release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 200</span><strong>Infrastructure DevSecOps and operations flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/01-terraform-modules.html"><span>200.01</span><strong>Terraform modules</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/02-remote-state.html"><span>200.02</span><strong>Remote state</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/03-infrastructure-pipelines.html"><span>200.03</span><strong>Infrastructure pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/04-policy-as-code.html"><span>200.04</span><strong>Policy as code</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/05-security-scanning.html"><span>200.05</span><strong>Security scanning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/06-azure-monitoring.html"><span>200.06</span><strong>Azure monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/07-incident-runbooks.html"><span>200.07</span><strong>Incident runbooks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/08-resilience-tests.html"><span>200.08</span><strong>Resilience tests</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/09-compliance-evidence.html"><span>200.09</span><strong>Compliance evidence</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-devops/200-infrastructure-devsecops-and-operations-flow/10-azure-devops-capstone.html"><span>200.10</span><strong>Azure DevOps capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="project-flows-azure-devops-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("project-flows-azure-devops-catalog");
#   const search = document.getElementById("project-flows-azure-devops-catalog-search");
#   const empty = document.getElementById("project-flows-azure-devops-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Azure DevOps** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
