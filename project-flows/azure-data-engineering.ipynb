# %% [raw]
# ---
# title: "Azure Data Engineering"
# description: "Complete notebook syllabus for Azure Data Engineering in Project Flows."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>azure-data-engineering.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Project Flows</span>
# <h1>Azure Data Engineering</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="azure-data-engineering/192-azure-data-platform-discovery-flow/01-business-outcomes.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Azure Data Engineering with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>6 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>Azure data-platform discovery flow</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-data-engineering/192-azure-data-platform-discovery-flow/01-business-outcomes.html">Business outcomes</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-data-engineering/192-azure-data-platform-discovery-flow/10-architecture-decision-record.html">Architecture decision record</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Ingestion and lake foundation flow</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/01-landing-zone-setup.html">Landing-zone setup</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/10-ingestion-release.html">Ingestion release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Lakehouse transformation flow</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-data-engineering/194-lakehouse-transformation-flow/01-bronze-design.html">Bronze design</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-data-engineering/194-lakehouse-transformation-flow/10-lakehouse-release.html">Lakehouse release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Analytics serving and governance flow</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-data-engineering/195-analytics-serving-and-governance-flow/01-warehouse-design.html">Warehouse design</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-data-engineering/195-analytics-serving-and-governance-flow/10-governed-analytics-release.html">Governed analytics release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Data-platform deployment and operations flow</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/01-source-control.html">Source control</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/10-azure-data-platform-capstone.html">Azure data-platform capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 06</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Azure Data Engineering outcome. Use <a href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/10-azure-data-platform-capstone.html">Azure data-platform capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Project Flows → Azure Data Engineering</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="192" href="azure-data-engineering/192-azure-data-platform-discovery-flow/01-business-outcomes.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 192</span><strong>Azure data-platform discovery flow</strong><small>Enter with Business outcomes. Demonstrate mastery through Architecture decision record.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="193" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/01-landing-zone-setup.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 193</span><strong>Ingestion and lake foundation flow</strong><small>Enter with Landing-zone setup. Demonstrate mastery through Ingestion release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="194" href="azure-data-engineering/194-lakehouse-transformation-flow/01-bronze-design.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 194</span><strong>Lakehouse transformation flow</strong><small>Enter with Bronze design. Demonstrate mastery through Lakehouse release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="195" href="azure-data-engineering/195-analytics-serving-and-governance-flow/01-warehouse-design.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 195</span><strong>Analytics serving and governance flow</strong><small>Enter with Warehouse design. Demonstrate mastery through Governed analytics release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="196" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/01-source-control.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 196</span><strong>Data-platform deployment and operations flow</strong><small>Enter with Source control. Demonstrate mastery through Azure data-platform capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Azure Data Engineering workflow</strong><p>Combine evidence from every stage and finish with Azure data-platform capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="project-flows-azure-data-engineering-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="project-flows-azure-data-engineering-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Azure Data Engineering syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="project-flows-azure-data-engineering-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 192</span><strong>Azure data-platform discovery flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/01-business-outcomes.html"><span>192.01</span><strong>Business outcomes</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/02-source-inventory.html"><span>192.02</span><strong>Source inventory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/03-volume-and-velocity.html"><span>192.03</span><strong>Volume and velocity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/04-data-classification.html"><span>192.04</span><strong>Data classification</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/05-consumer-needs.html"><span>192.05</span><strong>Consumer needs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/06-service-selection.html"><span>192.06</span><strong>Service selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/07-security-baseline.html"><span>192.07</span><strong>Security baseline</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/08-cost-model.html"><span>192.08</span><strong>Cost model</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/09-delivery-roadmap.html"><span>192.09</span><strong>Delivery roadmap</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/192-azure-data-platform-discovery-flow/10-architecture-decision-record.html"><span>192.10</span><strong>Architecture decision record</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 193</span><strong>Ingestion and lake foundation flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/01-landing-zone-setup.html"><span>193.01</span><strong>Landing-zone setup</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/02-adls-zones.html"><span>193.02</span><strong>ADLS zones</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/03-identity-and-networking.html"><span>193.03</span><strong>Identity and networking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/04-adf-connections.html"><span>193.04</span><strong>ADF connections</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/05-batch-ingestion.html"><span>193.05</span><strong>Batch ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/06-streaming-ingestion.html"><span>193.06</span><strong>Streaming ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/07-metadata-framework.html"><span>193.07</span><strong>Metadata framework</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/08-data-validation.html"><span>193.08</span><strong>Data validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/09-operational-logging.html"><span>193.09</span><strong>Operational logging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/193-ingestion-and-lake-foundation-flow/10-ingestion-release.html"><span>193.10</span><strong>Ingestion release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 194</span><strong>Lakehouse transformation flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/01-bronze-design.html"><span>194.01</span><strong>Bronze design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/02-silver-transformations.html"><span>194.02</span><strong>Silver transformations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/03-gold-models.html"><span>194.03</span><strong>Gold models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/04-spark-engineering.html"><span>194.04</span><strong>Spark engineering</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/05-delta-tables.html"><span>194.05</span><strong>Delta tables</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/06-incremental-processing.html"><span>194.06</span><strong>Incremental processing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/07-workflow-orchestration.html"><span>194.07</span><strong>Workflow orchestration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/08-data-quality-expectations.html"><span>194.08</span><strong>Data-quality expectations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/09-performance-optimization.html"><span>194.09</span><strong>Performance optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/194-lakehouse-transformation-flow/10-lakehouse-release.html"><span>194.10</span><strong>Lakehouse release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 195</span><strong>Analytics serving and governance flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/01-warehouse-design.html"><span>195.01</span><strong>Warehouse design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/02-synapse-serving.html"><span>195.02</span><strong>Synapse serving</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/03-fabric-serving.html"><span>195.03</span><strong>Fabric serving</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/04-semantic-models.html"><span>195.04</span><strong>Semantic models</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/05-access-controls.html"><span>195.05</span><strong>Access controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/06-catalogue-and-lineage.html"><span>195.06</span><strong>Catalogue and lineage</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/07-privacy-controls.html"><span>195.07</span><strong>Privacy controls</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/08-consumer-testing.html"><span>195.08</span><strong>Consumer testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/09-service-objectives.html"><span>195.09</span><strong>Service objectives</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/195-analytics-serving-and-governance-flow/10-governed-analytics-release.html"><span>195.10</span><strong>Governed analytics release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 196</span><strong>Data-platform deployment and operations flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/01-source-control.html"><span>196.01</span><strong>Source control</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/02-environment-strategy.html"><span>196.02</span><strong>Environment strategy</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/03-infrastructure-automation.html"><span>196.03</span><strong>Infrastructure automation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/04-pipeline-ci-cd.html"><span>196.04</span><strong>Pipeline CI/CD</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/05-testing-gates.html"><span>196.05</span><strong>Testing gates</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/06-monitoring.html"><span>196.06</span><strong>Monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/07-incident-response.html"><span>196.07</span><strong>Incident response</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/08-disaster-recovery.html"><span>196.08</span><strong>Disaster recovery</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/09-cost-optimization.html"><span>196.09</span><strong>Cost optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="azure-data-engineering/196-data-platform-deployment-and-operations-flow/10-azure-data-platform-capstone.html"><span>196.10</span><strong>Azure data-platform capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="project-flows-azure-data-engineering-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("project-flows-azure-data-engineering-catalog");
#   const search = document.getElementById("project-flows-azure-data-engineering-catalog-search");
#   const empty = document.getElementById("project-flows-azure-data-engineering-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Azure Data Engineering** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
