# %% [raw]
# ---
# title: "Full Stack AI"
# description: "Complete notebook syllabus for Full Stack AI in Project Flows."
# toc: false
# page-layout: full
# title-block-banner: false
# execute: false
# ---

# %% [markdown]
# <div class="course-workspace notebook-chrome">
# <div class="notebook-toolbar">
# <span class="notebook-file"><i class="bi bi-journal-code" aria-hidden="true"></i><strong>full-stack-ai.ipynb</strong></span>
# <span class="notebook-status"><i class="bi bi-check-circle-fill" aria-hidden="true"></i> Trusted</span>
# <span class="notebook-kernel"><i class="bi bi-diagram-3" aria-hidden="true"></i> Learning path</span>
# </div>
# <div class="course-workspace-hero">
# <span class="overview-kicker">Project Flows</span>
# <h1>Full Stack AI</h1>
# <p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson combines clear notes, a worked pattern, executable validation, a guided lab, a solution blueprint, practice, and knowledge checks.</p>
# <div class="course-tags"><span><i class="bi bi-signpost-split"></i> Foundation to advanced</span><span><i class="bi bi-code-square"></i> Hands-on practice</span><span><i class="bi bi-patch-check"></i> Review ready</span></div>
# <p class="course-start"><a class="btn btn-primary" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/01-business-problem.html"><i class="bi bi-play-fill"></i> Start the first notebook</a></p>
# </div>
# </div>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# <section class="learning-plan-section" id="learning-plan">
# <div class="path-section-heading"><div><span class="overview-kicker">Recommended schedule</span><h2>Learning plan</h2><p>A practical schedule for completing Full Stack AI with retained evidence, not passive reading.</p></div></div>
#
# <div class="plan-metrics">
# <div><i class="bi bi-calendar3"></i><span>Standard path</span><strong>7 weeks</strong><small>One topic each week, then integration</small></div>
# <div><i class="bi bi-lightning-charge"></i><span>Intensive path</span><strong>4 weeks</strong><small>Two topics each week, then integration</small></div>
# <div><i class="bi bi-clock"></i><span>Weekly commitment</span><strong>6–8 hours</strong><small>Study, code, practice, and reflection</small></div>
# <div><i class="bi bi-folder-check"></i><span>Finish line</span><strong>Portfolio evidence</strong><small>Tests, decisions, notes, and a capstone</small></div>
# </div>
#
# <div class="study-loop" aria-label="Weekly study loop">
# <div><span>01</span><i class="bi bi-book"></i><strong>Understand</strong><small>Read the notes and explain the mental model.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>02</span><i class="bi bi-play-circle"></i><strong>Run</strong><small>Execute the example and inspect every result.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>03</span><i class="bi bi-tools"></i><strong>Adapt</strong><small>Change the inputs and complete the guided lab.</small></div>
# <i class="bi bi-arrow-right study-loop-arrow" aria-hidden="true"></i>
# <div><span>04</span><i class="bi bi-patch-check"></i><strong>Prove</strong><small>Pass checks and retain reviewable evidence.</small></div>
# </div>
#
# <div class="plan-weeks">
# <details class="plan-week plan-topic-week" open>
# <summary><span class="plan-week-number">Week 01</span><strong>AI product discovery and architecture flow</strong><span class="plan-stage">Foundation</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/01-business-problem.html">Business problem</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/10-discovery-deliverable.html">Discovery deliverable</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 02</span><strong>Data and feature delivery flow</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="full-stack-ai/187-data-and-feature-delivery-flow/01-source-contracts.html">Source contracts</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="full-stack-ai/187-data-and-feature-delivery-flow/10-reusable-data-product.html">Reusable data product</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 03</span><strong>Machine-learning product flow</strong><span class="plan-stage">Core skills</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="full-stack-ai/188-machine-learning-product-flow/01-baseline-model.html">Baseline model</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="full-stack-ai/188-machine-learning-product-flow/10-ml-product-release.html">ML product release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 04</span><strong>Generative-AI application flow</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="full-stack-ai/189-generative-ai-application-flow/01-use-case-boundaries.html">Use-case boundaries</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="full-stack-ai/189-generative-ai-application-flow/10-genai-product-release.html">GenAI product release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 05</span><strong>Production RAG flow</strong><span class="plan-stage">Applied delivery</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="full-stack-ai/190-production-rag-flow/01-knowledge-source-inventory.html">Knowledge-source inventory</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="full-stack-ai/190-production-rag-flow/10-production-rag-release.html">Production RAG release</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><details class="plan-week plan-topic-week">
# <summary><span class="plan-week-number">Week 06</span><strong>Agentic-AI delivery flow</strong><span class="plan-stage">Integration & capstone</span></summary>
# <div class="plan-week-body">
# <div><span>Learn</span><p>Begin with <a href="full-stack-ai/191-agentic-ai-delivery-flow/01-workflow-selection.html">Workflow selection</a> and write the core mental model in your own words.</p></div>
# <div><span>Practice</span><p>Run, change, and explain the worked patterns across the middle lessons. Keep test evidence and questions.</p></div>
# <div><span>Demonstrate</span><p>Complete <a href="full-stack-ai/191-agentic-ai-delivery-flow/10-agentic-ai-capstone.html">Agentic-AI capstone</a> without copying the solution blueprint first.</p></div>
# </div>
# </details><div class="plan-integration-week">
# <span class="plan-week-number">Week 07</span>
# <div><strong>Integration, review, and portfolio evidence</strong><p>Connect the topic artifacts, close weak areas, and publish one reviewable Full Stack AI outcome. Use <a href="full-stack-ai/191-agentic-ai-delivery-flow/10-agentic-ai-capstone.html">Agentic-AI capstone</a> as the final checkpoint.</p></div>
# <i class="bi bi-trophy" aria-hidden="true"></i>
# </div>
# </div>
# </section>

# %% [markdown]
# <section class="learning-path-section" id="full-learning-path">
# <div class="path-section-heading"><div><span class="overview-kicker">Ordered progression</span><h2>Full learning path</h2><p>Follow every stage in sequence. Each stage links directly to its first notebook and ends with a concrete mastery checkpoint.</p></div><span class="path-route"><i class="bi bi-signpost-2"></i> Project Flows → Full Stack AI</span></div>
#
# <div class="learning-path">
# <a class="learning-path-step" data-topic="186" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/01-business-problem.html">
# <span class="path-index">01</span>
# <span class="path-step-copy"><span class="path-phase">Foundation · Topic 186</span><strong>AI product discovery and architecture flow</strong><small>Enter with Business problem. Demonstrate mastery through Discovery deliverable.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="187" href="full-stack-ai/187-data-and-feature-delivery-flow/01-source-contracts.html">
# <span class="path-index">02</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 187</span><strong>Data and feature delivery flow</strong><small>Enter with Source contracts. Demonstrate mastery through Reusable data product.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="188" href="full-stack-ai/188-machine-learning-product-flow/01-baseline-model.html">
# <span class="path-index">03</span>
# <span class="path-step-copy"><span class="path-phase">Core skills · Topic 188</span><strong>Machine-learning product flow</strong><small>Enter with Baseline model. Demonstrate mastery through ML product release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="189" href="full-stack-ai/189-generative-ai-application-flow/01-use-case-boundaries.html">
# <span class="path-index">04</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 189</span><strong>Generative-AI application flow</strong><small>Enter with Use-case boundaries. Demonstrate mastery through GenAI product release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="190" href="full-stack-ai/190-production-rag-flow/01-knowledge-source-inventory.html">
# <span class="path-index">05</span>
# <span class="path-step-copy"><span class="path-phase">Applied delivery · Topic 190</span><strong>Production RAG flow</strong><small>Enter with Knowledge-source inventory. Demonstrate mastery through Production RAG release.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a><a class="learning-path-step" data-topic="191" href="full-stack-ai/191-agentic-ai-delivery-flow/01-workflow-selection.html">
# <span class="path-index">06</span>
# <span class="path-step-copy"><span class="path-phase">Integration & capstone · Topic 191</span><strong>Agentic-AI delivery flow</strong><small>Enter with Workflow selection. Demonstrate mastery through Agentic-AI capstone.</small></span>
# <i class="bi bi-arrow-right" aria-hidden="true"></i>
# </a>
# </div>
#
# <div class="path-finish"><span><i class="bi bi-trophy-fill"></i></span><div><small>Completion milestone</small><strong>Connect the complete Full Stack AI workflow</strong><p>Combine evidence from every stage and finish with Agentic-AI capstone. You should be able to explain the architecture, reproduce the core workflow, diagnose failure, and defend the main tradeoffs.</p></div></div>
# </section>

# %% [markdown]
# <div class="syllabus-heading" id="notebook-syllabus">
# <div><span class="overview-kicker">Course contents</span><h2>Notebook syllabus</h2><p>Open a topic to browse its lessons, or search the complete course by concept.</p></div>
# <label class="syllabus-search" for="project-flows-full-stack-ai-catalog-search"><i class="bi bi-search" aria-hidden="true"></i><input id="project-flows-full-stack-ai-catalog-search" type="search" placeholder="Find a topic or lesson" autocomplete="off" aria-label="Search the Full Stack AI syllabus"></label>
# </div>
#
# <div class="curriculum-catalog" id="project-flows-full-stack-ai-catalog">
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 186</span><strong>AI product discovery and architecture flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/01-business-problem.html"><span>186.01</span><strong>Business problem</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/02-user-journeys.html"><span>186.02</span><strong>User journeys</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/03-success-metrics.html"><span>186.03</span><strong>Success metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/04-data-feasibility.html"><span>186.04</span><strong>Data feasibility</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/05-model-feasibility.html"><span>186.05</span><strong>Model feasibility</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/06-risk-assessment.html"><span>186.06</span><strong>Risk assessment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/07-architecture-options.html"><span>186.07</span><strong>Architecture options</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/08-delivery-roadmap.html"><span>186.08</span><strong>Delivery roadmap</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/09-experiment-plan.html"><span>186.09</span><strong>Experiment plan</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/186-ai-product-discovery-and-architecture-flow/10-discovery-deliverable.html"><span>186.10</span><strong>Discovery deliverable</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 187</span><strong>Data and feature delivery flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/01-source-contracts.html"><span>187.01</span><strong>Source contracts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/02-ingestion.html"><span>187.02</span><strong>Ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/03-validation.html"><span>187.03</span><strong>Validation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/04-cleaning.html"><span>187.04</span><strong>Cleaning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/05-exploration.html"><span>187.05</span><strong>Exploration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/06-feature-design.html"><span>187.06</span><strong>Feature design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/07-feature-pipelines.html"><span>187.07</span><strong>Feature pipelines</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/08-versioning.html"><span>187.08</span><strong>Versioning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/09-quality-monitoring.html"><span>187.09</span><strong>Quality monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/187-data-and-feature-delivery-flow/10-reusable-data-product.html"><span>187.10</span><strong>Reusable data product</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 188</span><strong>Machine-learning product flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/01-baseline-model.html"><span>188.01</span><strong>Baseline model</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/02-training-pipeline.html"><span>188.02</span><strong>Training pipeline</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/03-experiment-tracking.html"><span>188.03</span><strong>Experiment tracking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/04-evaluation.html"><span>188.04</span><strong>Evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/05-error-analysis.html"><span>188.05</span><strong>Error analysis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/06-model-packaging.html"><span>188.06</span><strong>Model packaging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/07-serving-api.html"><span>188.07</span><strong>Serving API</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/08-deployment.html"><span>188.08</span><strong>Deployment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/09-monitoring.html"><span>188.09</span><strong>Monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/188-machine-learning-product-flow/10-ml-product-release.html"><span>188.10</span><strong>ML product release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 189</span><strong>Generative-AI application flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/01-use-case-boundaries.html"><span>189.01</span><strong>Use-case boundaries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/02-model-selection.html"><span>189.02</span><strong>Model selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/03-prompt-design.html"><span>189.03</span><strong>Prompt design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/04-structured-outputs.html"><span>189.04</span><strong>Structured outputs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/05-tool-integration.html"><span>189.05</span><strong>Tool integration</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/06-guardrails.html"><span>189.06</span><strong>Guardrails</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/07-evaluation-suite.html"><span>189.07</span><strong>Evaluation suite</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/08-application-deployment.html"><span>189.08</span><strong>Application deployment</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/09-observability.html"><span>189.09</span><strong>Observability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/189-generative-ai-application-flow/10-genai-product-release.html"><span>189.10</span><strong>GenAI product release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 190</span><strong>Production RAG flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/01-knowledge-source-inventory.html"><span>190.01</span><strong>Knowledge-source inventory</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/02-document-ingestion.html"><span>190.02</span><strong>Document ingestion</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/03-chunking.html"><span>190.03</span><strong>Chunking</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/04-embedding-selection.html"><span>190.04</span><strong>Embedding selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/05-index-construction.html"><span>190.05</span><strong>Index construction</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/06-retrieval-design.html"><span>190.06</span><strong>Retrieval design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/07-grounded-generation.html"><span>190.07</span><strong>Grounded generation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/08-rag-evaluation.html"><span>190.08</span><strong>RAG evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/09-access-control.html"><span>190.09</span><strong>Access control</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/190-production-rag-flow/10-production-rag-release.html"><span>190.10</span><strong>Production RAG release</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 191</span><strong>Agentic-AI delivery flow</strong></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/01-workflow-selection.html"><span>191.01</span><strong>Workflow selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/02-tool-contracts.html"><span>191.02</span><strong>Tool contracts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/03-planning-design.html"><span>191.03</span><strong>Planning design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/04-memory-design.html"><span>191.04</span><strong>Memory design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/05-permission-model.html"><span>191.05</span><strong>Permission model</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/06-agent-evaluation.html"><span>191.06</span><strong>Agent evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/07-human-oversight.html"><span>191.07</span><strong>Human oversight</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/08-durable-execution.html"><span>191.08</span><strong>Durable execution</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/09-monitoring.html"><span>191.09</span><strong>Monitoring</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/191-agentic-ai-delivery-flow/10-agentic-ai-capstone.html"><span>191.10</span><strong>Agentic-AI capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# </div>
# <p class="syllabus-empty" id="project-flows-full-stack-ai-catalog-empty" hidden><i class="bi bi-search"></i> No matching lessons were found.</p>
#
# <script>
# document.addEventListener("DOMContentLoaded", () => {
#   const catalog = document.getElementById("project-flows-full-stack-ai-catalog");
#   const search = document.getElementById("project-flows-full-stack-ai-catalog-search");
#   const empty = document.getElementById("project-flows-full-stack-ai-catalog-empty");
#   if (!catalog || !search || !empty) return;
#
#   search.addEventListener("input", () => {
#     const query = search.value.trim().toLowerCase();
#     let visibleTopics = 0;
#     catalog.querySelectorAll(".curriculum-topic").forEach((topic) => {
#       const summary = topic.querySelector("summary");
#       const topicMatches = !query || summary.textContent.toLowerCase().includes(query);
#       let visibleLessons = 0;
#       topic.querySelectorAll(".topic-lesson-link").forEach((lesson) => {
#         const matches = topicMatches || lesson.textContent.toLowerCase().includes(query);
#         lesson.hidden = !matches;
#         if (matches) visibleLessons += 1;
#       });
#       const showTopic = topicMatches || visibleLessons > 0;
#       topic.hidden = !showTopic;
#       if (showTopic) visibleTopics += 1;
#       if (query && showTopic) topic.open = true;
#     });
#     empty.hidden = visibleTopics > 0;
#   });
# });
# </script>

# %% [markdown]
# ## Completion standard
#
# You have completed **Full Stack AI** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
