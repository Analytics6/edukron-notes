# %% [raw]
# ---
# title: "Replace with a useful, specific title"
# description: "One sentence explaining what the reader will understand or be able to do."
# author: "Your Name"
# date: "2026-09-08"
# categories: [topic, level]
# draft: true
# toc: true
# ---

# %% [markdown]
# Open with the practical question. Tell the reader what they will know by the end, and name any assumptions.
#
# ## The idea in one minute
#
# Give the intuition before notation. A small worked example is better than a paragraph of definitions.

# %%
# Keep setup visible and deterministic.
from random import seed
seed(42)
print("Notebook is ready.")
# Out:
# Notebook is ready.

# %% [markdown]
# ## A focused experiment
#
# Change one thing at a time. State what success looks like before running the cell.

# %%
values = [1, 2, 3, 4]
sum(values) / len(values)
# Out:
# 2.5

# %% [markdown]
# ## What to remember
#
# - State the main result in plain language.
# - Mention one limitation or boundary.
# - End with a small next experiment the reader can run.
#
# When the post is ready, move a copy into `posts/`, set `draft: false`, update the title/date/categories, and run `quarto preview`.
