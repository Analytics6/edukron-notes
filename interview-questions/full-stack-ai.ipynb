# %% [raw]
# ---
# title: "Full Stack AI"
# description: "Complete notebook syllabus for Full Stack AI in Interview Questions."
# author: "Edukron Notes"
# date: "2026-09-14"
# toc: true
# execute: false
# ---

# %% [markdown]
# <div class="overview-lead curriculum-summary">
# <div class="overview-icon"><i class="bi bi-journal-code" aria-hidden="true"></i></div>
# <div><span class="overview-kicker">Interview Questions</span><h2>Full Stack AI</h2><p>A complete notebook-first syllabus organized from foundations to applied delivery. Every lesson contains notes, a worked pattern, executable validation, a guided lab, solution blueprint, practice, and knowledge checks.</p></div>
# </div>
#
# <div class="course-stat-grid">
# <div><strong>6</strong><span>Syllabus topics</span></div>
# <div><strong>60</strong><span>Notebook lessons</span></div>
# <div><strong>Practice</strong><span>Labs and solutions</span></div>
# </div>
#
# <p class="course-start"><a class="btn btn-primary" href="full-stack-ai/171-python-and-sql-interview-preparation/01-python-language-questions.html">Start the first notebook <i class="bi bi-arrow-right"></i></a></p>

# %% [markdown]
# ## How to use this course
#
# Work through lessons in order for a complete pathway, or open a topic for focused reference. Type or adapt the examples, complete the guided lab before reading its blueprint, and preserve your test evidence as a portfolio artifact. Cloud and infrastructure examples are safe, copy-ready teaching patterns; execute them in your own sandbox only after substituting approved identities, names, and policies.

# %% [markdown]
# ## Full syllabus
#
# <details class="curriculum-topic" open>
# <summary><span class="topic-number">Topic 171</span><strong>Python and SQL interview preparation</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/01-python-language-questions.html"><span>171.01</span><strong>Python language questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/02-collections-and-complexity.html"><span>171.02</span><strong>Collections and complexity</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/03-functions-and-object-design.html"><span>171.03</span><strong>Functions and object design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/04-testing-and-debugging.html"><span>171.04</span><strong>Testing and debugging</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/05-python-coding-patterns.html"><span>171.05</span><strong>Python coding patterns</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/06-sql-query-fundamentals.html"><span>171.06</span><strong>SQL query fundamentals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/07-joins-and-subqueries.html"><span>171.07</span><strong>Joins and subqueries</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/08-window-functions.html"><span>171.08</span><strong>Window functions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/09-sql-optimization.html"><span>171.09</span><strong>SQL optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/171-python-and-sql-interview-preparation/10-mock-python-and-sql-interview.html"><span>171.10</span><strong>Mock Python-and-SQL interview</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 172</span><strong>Data science and statistics interviews</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/01-descriptive-statistics.html"><span>172.01</span><strong>Descriptive statistics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/02-probability-questions.html"><span>172.02</span><strong>Probability questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/03-sampling.html"><span>172.03</span><strong>Sampling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/04-hypothesis-testing.html"><span>172.04</span><strong>Hypothesis testing</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/05-confidence-intervals.html"><span>172.05</span><strong>Confidence intervals</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/06-experiment-design.html"><span>172.06</span><strong>Experiment design</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/07-data-cleaning-scenarios.html"><span>172.07</span><strong>Data cleaning scenarios</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/08-exploratory-analysis.html"><span>172.08</span><strong>Exploratory analysis</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/09-visualization-communication.html"><span>172.09</span><strong>Visualization communication</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/172-data-science-and-statistics-interviews/10-mock-analytics-interview.html"><span>172.10</span><strong>Mock analytics interview</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 173</span><strong>Machine-learning interviews</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/01-ml-foundations.html"><span>173.01</span><strong>ML foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/02-feature-engineering.html"><span>173.02</span><strong>Feature engineering</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/03-model-selection.html"><span>173.03</span><strong>Model selection</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/04-regression-questions.html"><span>173.04</span><strong>Regression questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/05-classification-questions.html"><span>173.05</span><strong>Classification questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/06-tree-model-questions.html"><span>173.06</span><strong>Tree-model questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/07-evaluation-metrics.html"><span>173.07</span><strong>Evaluation metrics</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/08-overfitting-and-regularization.html"><span>173.08</span><strong>Overfitting and regularization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/09-deployment-scenarios.html"><span>173.09</span><strong>Deployment scenarios</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/173-machine-learning-interviews/10-mock-ml-interview.html"><span>173.10</span><strong>Mock ML interview</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 174</span><strong>Deep learning and generative-AI interviews</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/01-neural-network-foundations.html"><span>174.01</span><strong>Neural-network foundations</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/02-backpropagation.html"><span>174.02</span><strong>Backpropagation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/03-optimization.html"><span>174.03</span><strong>Optimization</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/04-cnn-questions.html"><span>174.04</span><strong>CNN questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/05-sequence-model-questions.html"><span>174.05</span><strong>Sequence-model questions</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/06-transformer-architecture.html"><span>174.06</span><strong>Transformer architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/07-generative-model-concepts.html"><span>174.07</span><strong>Generative-model concepts</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/08-prompt-engineering.html"><span>174.08</span><strong>Prompt engineering</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/09-safety-and-evaluation.html"><span>174.09</span><strong>Safety and evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/174-deep-learning-and-generative-ai-interviews/10-mock-deep-learning-interview.html"><span>174.10</span><strong>Mock deep-learning interview</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 175</span><strong>LLM RAG and agent interviews</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/01-tokenization-and-embeddings.html"><span>175.01</span><strong>Tokenization and embeddings</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/02-llm-inference.html"><span>175.02</span><strong>LLM inference</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/03-fine-tuning-tradeoffs.html"><span>175.03</span><strong>Fine-tuning tradeoffs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/04-rag-architecture.html"><span>175.04</span><strong>RAG architecture</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/05-retrieval-evaluation.html"><span>175.05</span><strong>Retrieval evaluation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/06-grounded-generation.html"><span>175.06</span><strong>Grounded generation</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/07-tool-calling.html"><span>175.07</span><strong>Tool calling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/08-agent-planning.html"><span>175.08</span><strong>Agent planning</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/09-agent-safety.html"><span>175.09</span><strong>Agent safety</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/175-llm-rag-and-agent-interviews/10-mock-llm-systems-interview.html"><span>175.10</span><strong>Mock LLM-systems interview</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>
# <details class="curriculum-topic">
# <summary><span class="topic-number">Topic 176</span><strong>AI system design and behavioral interviews</strong><span>10 notebooks</span></summary>
# <div class="topic-lessons">
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/01-requirements-clarification.html"><span>176.01</span><strong>Requirements clarification</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/02-architecture-decomposition.html"><span>176.02</span><strong>Architecture decomposition</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/03-data-and-model-choices.html"><span>176.03</span><strong>Data and model choices</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/04-scale-and-latency.html"><span>176.04</span><strong>Scale and latency</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/05-reliability.html"><span>176.05</span><strong>Reliability</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/06-security-and-governance.html"><span>176.06</span><strong>Security and governance</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/07-cost-tradeoffs.html"><span>176.07</span><strong>Cost tradeoffs</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/08-project-storytelling.html"><span>176.08</span><strong>Project storytelling</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/09-behavioral-frameworks.html"><span>176.09</span><strong>Behavioral frameworks</strong><i class="bi bi-arrow-right"></i></a>
# <a class="topic-lesson-link" href="full-stack-ai/176-ai-system-design-and-behavioral-interviews/10-full-stack-ai-interview-capstone.html"><span>176.10</span><strong>Full Stack AI interview capstone</strong><i class="bi bi-arrow-right"></i></a>
# </div>
# </details>

# %% [markdown]
# ## Completion standard
#
# You have completed **Full Stack AI** when you can explain each topic, reproduce its core workflow, pass the notebook checks, defend the main tradeoffs, and combine the lessons into one reviewable portfolio project. Use the practice tasks as evidence rather than treating page reading alone as completion.
