# %% [raw]
# ---
# title: "Full Stack AI — Overview"
# description: "Interview preparation across Python, SQL, data science, ML, LLMs, RAG, and agents."
# author: "Edukron Notes"
# date: "2026-09-09"
# categories: [Interview-track-overview, interview-questions]
# toc: true
# page-layout: article
# execute: false
# ---

# %% [markdown]
# <section class="course-overview-hero">
#   <span class="overview-eyebrow">Interview-track overview</span>
#   <p>Interview preparation across Python, SQL, data science, ML, LLMs, RAG, and agents.</p>
# </section>
#
# <div class="overview-meta">
#   <div><span>Learning path</span><strong>Interview Questions</strong></div>
#   <div><span>Format</span><strong>Jupyter notebooks</strong></div>
#   <div><span>Content status</span><strong>Overview ready</strong></div>
# </div>

# %% [markdown]
# ## Purpose
#
# This page is the permanent overview for **Full Stack AI** inside the **Interview Questions** learning path. It establishes where the material will live and how learners will move through it. The detailed syllabus is intentionally open until you provide the course contents.

# %% [markdown]
# ## Notebook format
#
# Every approved topic will be published as a focused `.ipynb` lesson using the same readable structure:
#
# <div class="overview-grid">
#   <div class="overview-card"><strong>Concept checks</strong><span>Clear definitions and concise explanations.</span></div>
#   <div class="overview-card"><strong>Scenario questions</strong><span>Trade-offs, diagnosis, and design decisions.</span></div>
#   <div class="overview-card"><strong>Practical rounds</strong><span>Code, SQL, configuration, and troubleshooting prompts.</span></div>
#   <div class="overview-card"><strong>Answer guides</strong><span>Short answer, deep dive, example, and follow-up format.</span></div>
# </div>

# %% [markdown]
# ## Content status
#
# ::: {.callout-note}
# ### Ready for your material
# The navigation and overview are published first. No detailed curriculum has been invented or locked in.
# :::
#
# | Overview component | Current status |
# |---|---|
# | Question groups | Awaiting your topic list |
# | Difficulty levels | Awaiting your preference |
# | Answer depth | Awaiting your examples or notes |
# | Mock interview set | Added after questions are approved |

# %% [markdown]
# ## What to send next
#
# Send the questions or topic groups you want covered, plus the expected experience level and preferred answer depth.
#
# [← Back to Interview Questions](index.html)
